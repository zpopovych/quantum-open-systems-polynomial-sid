# %% [markdown]
# # Identification of Lindblad form Markovian ME
# ## (for spin-boson system using TSSOS POP method)

# %%
include("LiPoSID.jl")

using QuantumOptics
basis = NLevelBasis(2)
using LinearAlgebra

using HDF5
using DynamicPolynomials

using Dates

using Statistics

using TSSOS

# %% [markdown]
# In this notebook we identify and test accuracy of Markovian master equations in Lindblad form for the nontrivial example of the data generated by the full-featured simulation of the spin-boson model (two-level system coupled with the bath of the continuum of the harmonic oscillators).

# %% [markdown]
# Consider simple Lindblad master equation with two dissipators:
#
# $
#     \frac{d\rho}{dt} = \mathcal{L}[\rho(t)] = -\frac{i}{\hbar} [H,\rho(t)] + \mathcal{D}[\rho(t)] = - \frac{i}{\hbar}[H, \rho]+\sum_{\ell=1}^{s-1}\left[J_\ell \rho J_\ell^\dagger - \frac{1}{2}\left\{ J_\ell^\dagger J_\ell, \rho \right\} \right],
# $

# %%
function lindblad_rhs(ρ, H, J::Array)
       """
       Right hand side of the Lindblad master equation with multiple disipators
       """
      
       Σ = sum([ ( Jⱼ * ρ * Jⱼ' - (Jⱼ' * Jⱼ  * ρ + ρ * Jⱼ' * Jⱼ)/2 ) for Jⱼ in J ])
       
       return -im * (H * ρ - ρ * H) + Σ 
       
   end
# Out:
# lindblad_rhs (generic function with 1 method)

# %% [markdown]
# where Hamiltonian is hermitian with one of the diagonal elemnets set to zero
#
#
# $
#     H = \begin{pmatrix} \epsilon & \alpha + i \beta \\ \alpha - i \beta  & -\epsilon
#    \end{pmatrix}/2
# $
#
# here we consider the following set of jump operators ot the particular ansatz form:
#
# $
# J_1 = \begin{pmatrix} 0 & r \\ 0 & 0
#    \end{pmatrix} =
#    \begin{pmatrix} 0 & \sqrt{\gamma_1} \\ 0 & 0
#    \end{pmatrix}
# $  - for relaxation process,

# %% [markdown]
# and three following operators for depolarization process:
#
# $
# J_2 = \begin{pmatrix} 0 & p \\ p & 0
#    \end{pmatrix} = \sqrt{\gamma_4/3}
#    \begin{pmatrix} 0 & 1\\ 1 & 0
#    \end{pmatrix}
# $
#
# $
# J_3 = \begin{pmatrix} 0 & -i p \\ i p & 0
#    \end{pmatrix} = \sqrt{\gamma_4/3}
#    \begin{pmatrix} 0 & -i \\ i & 0
#    \end{pmatrix}
# $
#
# $
# J_4 = \begin{pmatrix} p & 0 \\ 0 & -p
#    \end{pmatrix} = \sqrt{\gamma_4/3}
#    \begin{pmatrix} 1 & 0 \\ 0 & -1
#    \end{pmatrix}
# $

# %%
# Define polynomial variables
@polyvar ϵ α β r p

Hˢʸᵐᵇ = [ ϵ            α + im* β
          α - im* β   -ϵ         ]/2

J₁ˢʸᵐᵇ = [ 0   r
           0   0. ]

J₂ˢʸᵐᵇ = p * [ 0    1
               1    0. ]

J₃ˢʸᵐᵇ = p * [ 0   -im
               im   0  ]

J₄ˢʸᵐᵇ = p * [ 1    0
               0   -1. ]


Jˢʸᵐᵇ = [ J₁ˢʸᵐᵇ, J₂ˢʸᵐᵇ, J₃ˢʸᵐᵇ, J₄ˢʸᵐᵇ]
# Out:
# 4-element Vector{Matrix}:
#  Term{true, Float64}[0.0 r; 0.0 0.0]
#  Term{true, Float64}[0.0 p; p 0.0]
#  Term{true, Complex{Int64}}[(0 + 0im) (0 - 1im)p; (0 + 1im)p (0 + 0im)]
#  Term{true, Float64}[p 0.0; 0.0 -p]

# %% [markdown]
# To ensure the objective is polynomial we can write loss function with double step and using the Frobenius norm :
#
# $ L = \sum_{j=3}^N
# {\left\| \rho_j - \rho_{j-2} - {\mathcal{L}} \left[\int^{t_j}_{t_{j-2}}\rho(t)dt \right] \right\| }^2_F $
#
# and apply the Simpson approximation method to evaluate the integral:
#
# $
# \int^{t_j}_{t_{j-2}}\rho(t)dt = \frac{1}{3} \Delta t \left[ \rho_{j-2} + 4 \rho_{j-1} + \rho_j \right] +  \mathcal{O}(\Delta t^5).$
#
# Using it we can calculate objective as polynomial of nine variables  and cast the optimization problem:
#
# $
# \min L\left( \epsilon, \alpha, \beta, r, p, \{\rho_k\} \right)
# $

# %%
function simpson_obj(ρ, t, H, J)
    
    obj = 0
    for i in 3:length(ρ)
        obj += LiPoSID.frobenius_norm2(
            ρ[i] - ρ[i-2] - (t[i]-t[i-1])lindblad_rhs((ρ[i-2] + 4ρ[i-1] + ρ[i])/3, H, J)
        )
    end
    obj = sum(real(coef) * mon for (coef, mon) in zip(coefficients(obj), monomials(obj)))
    return obj
end
# Out:
# simpson_obj (generic function with 1 method)

# %% [markdown]
# Density matrices for four bases initial states $\ket{0}$, $\ket{1}$, $\ket{x}$, $\ket{y}$ that were used to simulate training data are defined as follows:
# \begin{align}
#    \rho^{(g)}_0 &=  \rho^{\ket{0}}_0 = \left(
# \begin{array}{c}
#             1  \\
#             0   \\
#         \end{array}
#                 \right)
#                 \left(
#                 \begin{array} {cc}
#                 1 & 0
#                 \end{array}
#                 \right) =
# \ket{0} \bra{0} = \left(
#         \begin{array}{ccccc}
#             1  &  0  \\
#             0  &  0   \\
#         \end{array}
#             \right),\\
# \rho^{(e)}_0 &=\rho^{\ket{1}}_0 =\ket{1} \bra{1} =
# \begin{pmatrix}
# 0 \\ 1
# \end{pmatrix}
# \begin{pmatrix}
# 0 & 1
# \end{pmatrix}=
# \left(
#         \begin{array}{ccccc}
#             0  &  0  \\
#             0  &  1  \\
#         \end{array}
#             \right), \notag\\
# \rho^{\ket{x}}_0 &=\ket{x} \bra{x} = |+\rangle \langle + | = \left(
# \begin{array}{c}
#             1/\sqrt{2}  \\
#             1/\sqrt{2}   \\
#         \end{array}
#                 \right)
#                 \left(
#                 \begin{array} {cc}
#                 1/\sqrt{2} & 1/\sqrt{2}
#                 \end{array}
#                 \right) = \frac{1}{2}\left(
#         \begin{array}{ccccc}
#             1  &  1  \\
#             1  &  1   \\
#         \end{array}
#     \right), \notag\\
# \rho^{\ket{y}}_0  &= \ket{y} \bra{y} = |-\rangle \langle-| = \left(
# \begin{array}{c}
#             1/\sqrt{2}  \\
#             i/\sqrt{2}   \\
#         \end{array}
#                 \right)
#                 \left(
#                 \begin{array} {cc}
#                 1/\sqrt{2} & -i/\sqrt{2}
#                 \end{array}
#                 \right) = \frac{1}{2}\left(
#         \begin{array}{ccccc}
#             1  &  -i  \\
#             i  &  1   \\
#         \end{array}
#     \right)
# \end{align}
#
# The function `lindblad_GEXY_obj()`
# below combines the objective for the for data series of density matrices starting in four basis states
# $\ket{0}$, $\ket{1}$, $\ket{x}$, $\ket{y}$:

# %%
function lindblad_GEXY_obj(ρᵍᵉˣʸ, tᵍᵉˣʸ, Hˢʸᵐᵇ, Jˢʸᵐᵇ)

    ρᵍ, ρᵉ, ρˣ, ρʸ = ρᵍᵉˣʸ
    tᵍ, tᵉ, tˣ, tʸ = tᵍᵉˣʸ

    polyG = simpson_obj(ρᵍ, tᵍ, Hˢʸᵐᵇ, Jˢʸᵐᵇ)
    polyE = simpson_obj(ρᵉ, tᵉ, Hˢʸᵐᵇ, Jˢʸᵐᵇ)
    polyX = simpson_obj(ρˣ, tˣ, Hˢʸᵐᵇ, Jˢʸᵐᵇ)
    polyY = simpson_obj(ρʸ, tʸ, Hˢʸᵐᵇ, Jˢʸᵐᵇ)

    polyGEXY = polyG + polyE + polyX + polyY

    return polyGEXY
end
# Out:
# lindblad_GEXY_obj (generic function with 1 method)

# %%
constraints = [ϵ, p] #r, e, ϕ, p]
# Out:
# 2-element Vector{PolyVar{true}}:
#  ϵ
#  p

# %%
# Here we set parameters what data to use for training and testing

evol_data_file_name = "DATA/ALL_GAMMAS_B4_D10.h5"

tests_dir = ""

ρᵍ₀ = [ 1 0
        0 0 ]    # state to measure initial distance from

dodeca_10_states = ["D"*string(n) for n=1:10];
basis_states = ["B"*string(n) for n=1:4];

train_states = basis_states 
test_states = dodeca_10_states

all_states = vcat(train_states, test_states);

# %% [markdown]
# Checking functions on one particular coupling level

# %%
γᵢ = "0.25133"

tᵍᵉˣʸ , ρᵍᵉˣʸ  = LiPoSID.read_GEXY_timeevolution(evol_data_file_name, γᵢ)
polyGEXYfull = lindblad_GEXY_obj(ρᵍᵉˣʸ, tᵍᵉˣʸ, Hˢʸᵐᵇ, Jˢʸᵐᵇ)
# Out:
# 0.18256809044653088r⁴ - 0.03750921946960905r²p² + 17.65754243030726p⁴ + 0.0012278271223203374αr² - 0.0008250182359115586βr² + 0.10341163322607885ϵ² - 4.104630886766604e-5ϵα + 3.451755329501484e-5ϵβ + 1.0519096548020683α² + 0.000517967623618515αβ + 1.0518715157602614β² - 0.09164160023232439r² + 0.0032558121009390465p² - 5.199679015672933ϵ + 0.00013669789552732257α - 0.00035392288736811714β + 65.37495321955478

# %%
variables(polyGEXYfull)'
# Out:
# 1×5 adjoint(::Vector{PolyVar{true}}) with eltype PolyVar{true}:
#  ϵ  α  β  r  p

# %%
LiPoSID.coefficient_range(polyGEXYfull)
# Out:
# 5.279935448533528e-7

# %% [markdown]
# Below is the wrapper function to call the TSSOS library function for the constraint polynomial optimization:

# %%
function min_cs_tssos(p, constrs)

    coeffs = coefficients(p)
    reg_coef = 0

    pop =[p+reg_coef*sum(variables(p).^2), constrs...] ./ maximum(abs.(coeffs))

    d = maxdegree(p)
    
    # Initial optimization step
    opt, sol, data = cs_tssos_first(pop, variables(pop), d; solution=true, QUIET=true)
    ref_sol, flag = TSSOS.refine_sol(opt, sol, data; QUIET=true)
    prev_opt, prev_sol, prev_data = opt, sol, data 

    # Check if the solution needs further refinement
    if flag != 0
        while ~isnothing(sol) && flag != 0
            prev_opt, prev_sol, prev_data = opt, sol, data
            opt, sol, data = cs_tssos_higher!(data; solution=true, QUIET=true) 
        end
        ref_sol, flag = TSSOS.refine_sol(prev_opt, prev_sol, prev_data; QUIET=true)
    end

    solution = variables(p) => ref_sol

    if flag == 0 
        status_name = "GLOBAL"
    else
        status_name = "LOCAL/FAIL"
    end

    return solution, status_name

end
# Out:
# min_cs_tssos (generic function with 1 method)

# %%
sol, st = min_cs_tssos(polyGEXYfull, constraints)
# Out:
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 6.963919247976713e-9
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Global optimality certified with relative optimality gap 0.002601%!
# Global optimality certified with relative optimality gap 0.002601%!
# (PolyVar{true}[ϵ, α, β, r, p] => [25.140687157086514, 0.0002790776568615105, -0.00014590158300080663, 0.5009961700124128, 0.013669214257062093], "GLOBAL")

# %%
Hˢⁱᵈ = convert.(ComplexF64,subs(Hˢʸᵐᵇ, sol))
Hˢⁱᵈ[1:2,1:2]
# Out:
# 2×2 Matrix{ComplexF64}:
#      12.5703+0.0im         0.000139539-7.29508e-5im
#  0.000139539+7.29508e-5im     -12.5703+0.0im

# %%
sol, st = min_cs_tssos(LiPoSID.filter_odd_terms_by_relative_threshold(polyGEXYfull, 1e-4), constraints)
# Out:
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [2, 1]
# [1, 3]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 7.455967800350148e-10
# Global optimality certified with relative optimality gap 0.002602%!
# Global optimality certified with relative optimality gap 0.002602%!
# (PolyVar{true}[ϵ, α, β, r, p] => [25.140687077350453, 0.0, 0.0, 0.5009974357225474, 0.013669260403264221], "GLOBAL")

# %%
st
# Out:
# "GLOBAL"

# %%
J₁ˢⁱᵈ = convert.(ComplexF64,subs(J₁ˢʸᵐᵇ, sol))
J₁ˢⁱᵈ[1:2,1:2]
# Out:
# 2×2 Matrix{ComplexF64}:
#  0.0+0.0im  0.500997+0.0im
#  0.0+0.0im       0.0+0.0im

# %%
Hˢⁱᵈ = convert.(ComplexF64, subs(Hˢʸᵐᵇ, sol))
# Out:
# 2×2 Matrix{ComplexF64}:
#  12.5703+0.0im       0.0+0.0im
#      0.0+0.0im  -12.5703+0.0im

# %% [markdown]
# Below we perform system identification and testing of the accuracy of identified models for all available coupling levels of spin boson system:

# %%
println(" MULTI DURATION SYSTEM IDENTIFICATION w CONSTRAINED TSSOS and LINDBLAD 4ops Frobenius objective QO simulation")

γ = [ "0.079477",  "0.25133", "0.79477", "2.5133", "7.9477", "25.133", "79.477", "251.33"]

date_and_time_string = string(Dates.format(now(), "yyyy-u-dd_at_HH-MM"))

evol_data_file_name = "DATA/ALL_GAMMAS_B4_D10.h5"

relative_threshold = 1e-15

rltrs = string(convert(Int, floor(log10(relative_threshold))))

tests_data_file_name = "MULT_LINDBLAD_CONSTR_TSSOS_threshold_1e"*rltrs*"_FROB_QO_"*date_and_time_string * ".h5"

FminGammas = []
FmedianGammas = []
FmeanGammas = []
Epsilons = []
CoefRanges = []

for γᵢ in γ
    println("γ =  "*γᵢ)

    # Save results into HDF5
    h5open(tests_dir*tests_data_file_name,"cw") do fid
        γ_group = create_group(fid, γᵢ) # Create gamma coupling group
    end
    
    # Read time series data for the current γ
    tᵍᵉˣʸ, ρᵍᵉˣʸ = LiPoSID.read_GEXY_timeevolution(evol_data_file_name, γᵢ)
    tᵍ, tᵉ, tˣ, tʸ = tᵍᵉˣʸ
    
    # Find the end of the shortest time series
    t_end = minimum([tᵍ[end], tᵉ[end], tˣ[end], tʸ[end]])

    # Dynamically generate the duration steps
    max_steps = Int(floor(t_end * 2 * parse(Float64, γᵢ)))  # Maximum steps based on t_end and γᵢ
    duration_steps = [i/(2*parse(Float64, γᵢ)) for i in 1:max_steps]  # Generates dynamic steps up to t_end
    
    # Ensure steps do not exceed the shortest time series
    duration_steps = duration_steps[duration_steps .<= t_end]

    for t_duration in duration_steps
        println("Processing time duration: ", t_duration)

        elapsed_time = @timed begin
            # Masking the time series up to t_duration
            t_masked = [t[t .<= t_duration] for t in [tᵍ, tᵉ, tˣ, tʸ]]
            min_length = minimum(length.(t_masked))  # Ensure all time series are truncated to the same length
            t_masked = [t[1:min_length] for t in t_masked]

            ρ_masked = [ρ[1:min_length] for ρ in ρᵍᵉˣʸ] # Truncate ρᵍᵉˣʸ accordingly

            # Objective function construction and minimization
            polyGEXYfull = lindblad_GEXY_obj(ρ_masked, t_masked, Hˢʸᵐᵇ, Jˢʸᵐᵇ)
            polyGEXY = LiPoSID.filter_odd_terms_by_relative_threshold(polyGEXYfull, relative_threshold)
            sol, status = min_cs_tssos(polyGEXY, constraints)
        end

        @show minimum(abs.(coefficients(polyGEXY)))
        @show maximum(abs.(coefficients(polyGEXY)))
        push!(CoefRanges, LiPoSID.coefficient_range(polyGEXYfull))

        print(" status:", status)
        print(" runtime :", elapsed_time.time)

        Hˢⁱᵈ = convert.(ComplexF64, subs(Hˢʸᵐᵇ, sol))
        Jˢⁱᵈ = [convert.(ComplexF64,subs(Jᵢˢʸᵐᵇ, sol)) for Jᵢˢʸᵐᵇ in Jˢʸᵐᵇ]

        epsilon = subs(ϵ, sol)
        push!(Epsilons, epsilon)

        # Save results into HDF5
        h5open(tests_dir*tests_data_file_name,"cw") do fid
            γ_group = open_group(fid, γᵢ) # Create gamma coupling group
            t_group = create_group(γ_group, string(t_duration)) # Create time duration group
            t_group["epsilon"] = convert(Float64, epsilon)
            t_group["H"] = convert.(ComplexF64, Hˢⁱᵈ)
            t_group["J1"] = convert.(ComplexF64, Jˢⁱᵈ[1])
            t_group["J2"] = convert.(ComplexF64, Jˢⁱᵈ[2])
            t_group["J3"] = convert.(ComplexF64, Jˢⁱᵈ[3])
            t_group["J4"] = convert.(ComplexF64, Jˢⁱᵈ[4])
            t_group["status"] = status
            t_group["runtime"] = elapsed_time.time
        end

        println()

        FminStates = []
        FmedianStates = []
        FmeanStates = []

        print("Processing states: ")

        for state in test_states # Loop over initial states
            print(state*" ")
            start_time = time()

            tₛ, ρₛ = LiPoSID.read_timeevolution(evol_data_file_name, state, γᵢ)
            ρₛ = convert(Vector{Matrix{ComplexF64}}, ρₛ)
            ρᵗˢᵗ = [DenseOperator(basis, Hermitian(ρₜ)) for ρₜ in ρₛ]
            tᵗˢᵗ = convert(Vector{Float64}, tₛ)

            ρₒ = DenseOperator(basis, ρₛ[1])
            dt = tᵗˢᵗ[2] - tᵗˢᵗ[1]
            tᵉⁿᵈ = tᵗˢᵗ[end]

            effective_Lindblad = Jˢⁱᵈ
            effective_Lindblad_ops = [DenseOperator(basis, j) for j in effective_Lindblad]

            tout, ρ_t_kossak = timeevolution.master(convert.(Float64, tᵗˢᵗ), ρₒ, DenseOperator(basis, Hˢⁱᵈ), effective_Lindblad_ops)
            ρˢⁱᵈ = [ρₜ.data for ρₜ in ρ_t_kossak]

            F = LiPoSID.fidelity_series(basis, ρₛ, ρˢⁱᵈ)

            FminState = minimum(F)
            FmedianState = mean(F)
            FmeanState = mean(F)

            h5open(tests_dir*tests_data_file_name,"cw") do fid
                γ_group = open_group(fid, γᵢ)
                t_group = open_group(γ_group, string(t_duration))
                init_state_group = create_group(t_group, state)
                init_state_group["Fidelity"] = convert.(Float64, F)
                init_state_group["Fmin"] = convert(Float64, FminState)
                init_state_group["Fmedian"] = convert(Float64, FmedianState)
                init_state_group["Fmean"] = convert(Float64, FmeanState)

                init_state_group["tr_dist_grnd"] = LiPoSID.TrDist(ρₛ[1], ρᵍ₀)
                init_state_group["time"] = tᵗˢᵗ
            end

            push!(FminStates, FminState)
            push!(FmedianStates, FmedianState)
            push!(FmeanStates, FmeanState)
        end

        F_mean_value = mean(FmeanStates)
        F_median_value = median(FmedianStates)
        F_min_value = minimum(FminStates)

        push!(FminGammas, F_min_value)
        push!(FmedianGammas, F_median_value)
        push!(FmeanGammas, F_mean_value)

        println("Median fidelity for γ = "*γᵢ*" and time duration "*string(t_duration)*": ", F_median_value)

    end
end
    
    
println(tests_data_file_name)
# Out:
#  MULTI DURATION SYSTEM IDENTIFICATION w CONSTRAINED TSSOS and LINDBLAD 4ops Frobenius objective QO simulation
# γ =  0.079477
# Processing time duration: 6.291128250940523
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 7.012549719112515e-9
# Global optimality certified with relative optimality gap 0.002691%!
# Global optimality certified with relative optimality gap 0.000252%!
# minimum(abs.(coefficients(polyGEXY))) = 0.00018176880830710583
# maximum(abs.(coefficients(polyGEXY))) = 226.05632125567843
#  status:GLOBAL runtime :1.022256815
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.079477 and time duration 6.291128250940523: 0.999603474928597
# Processing time duration: 12.582256501881046
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.24859616050164085
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00000252.
# The relative optimality gap is: 24.859364%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00000252.
# The relative optimality gap is: 24.859364%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.2604709278156197
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00000252.
# The relative optimality gap is: 26.046841%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00000252.
# The relative optimality gap is: 26.046841%.
# minimum(abs.(coefficients(polyGEXY))) = 0.0009093241481444273
# maximum(abs.(coefficients(polyGEXY))) = 365.88037819973215
#  status:LOCAL/FAIL runtime :2.721487354
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.079477 and time duration 12.582256501881046: 0.9996296808382408
# Processing time duration: 18.87338475282157
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.217904146753551e-8
# Global optimality certified with relative optimality gap 0.000251%!
# Global optimality certified with relative optimality gap 0.000251%!
# minimum(abs.(coefficients(polyGEXY))) = 0.0003092765140046144
# maximum(abs.(coefficients(polyGEXY))) = 450.42156952171655
#  status:GLOBAL runtime :2.516579041
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.079477 and time duration 18.87338475282157: 0.9996311978612613
# γ =  0.25133
# Processing time duration: 1.9894163052560379
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 8.368684876439113e-9
# Global optimality certified with relative optimality gap 0.002554%!
# Global optimality certified with relative optimality gap 0.002554%!
# minimum(abs.(coefficients(polyGEXY))) = 0.00018614975117352517
# maximum(abs.(coefficients(polyGEXY))) = 25.15925299229987
#  status:GLOBAL runtime :0.83055675
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 1.9894163052560379: 0.9999955817605239
# Processing time duration: 3.9788326105120757
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.2763738438325358
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00002538.
# The relative optimality gap is: 27.634846%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00002538.
# The relative optimality gap is: 27.634846%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 6.159481696544831e-9
# Global optimality certified with relative optimality gap 0.002538%!
# No higher TS step of the CS-TSSOS hierarchy!
# Global optimality certified with relative optimality gap 0.002538%!
# minimum(abs.(coefficients(polyGEXY))) = 5.121019753568794e-5
# maximum(abs.(coefficients(polyGEXY))) = 41.03190823996914
#  status:GLOBAL runtime :1.694673098
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 3.9788326105120757: 0.9999962983607771
# Processing time duration: 5.968248915768114
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 8.352651382522491e-9
# Global optimality certified with relative optimality gap 0.002532%!
# Global optimality certified with relative optimality gap 0.002532%!
# minimum(abs.(coefficients(polyGEXY))) = 3.416302550344856e-5
# maximum(abs.(coefficients(polyGEXY))) = 50.69000952743874
#  status:GLOBAL runtime :2.266177672
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 5.968248915768114: 0.9999987656788936
# Processing time duration: 7.957665221024151
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.216900757532906e-8
# Global optimality certified with relative optimality gap 0.002529%!
# Global optimality certified with relative optimality gap 0.002529%!
# minimum(abs.(coefficients(polyGEXY))) = 0.0001745737178131255
# maximum(abs.(coefficients(polyGEXY))) = 56.526826742044186
#  status:GLOBAL runtime :2.908635104
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 7.957665221024151: 0.9999986816216875
# Processing time duration: 9.94708152628019
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 4.8982086384101216e-9
# Global optimality certified with relative optimality gap 0.002529%!
# Global optimality certified with relative optimality gap 0.002529%!
# minimum(abs.(coefficients(polyGEXY))) = 0.0001947432820489684
# maximum(abs.(coefficients(polyGEXY))) = 60.07853609095635
#  status:GLOBAL runtime :3.604443393
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 9.94708152628019: 0.9999986504128423
# Processing time duration: 11.936497831536228
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 3.9381152333250106e-9
# Global optimality certified with relative optimality gap 0.002528%!
# Global optimality certified with relative optimality gap 0.002528%!
# minimum(abs.(coefficients(polyGEXY))) = 0.0002215921319561827
# maximum(abs.(coefficients(polyGEXY))) = 62.22507217452367
#  status:GLOBAL runtime :4.302705074
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 11.936497831536228: 0.9999986647703057
# Processing time duration: 13.925914136792265
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 9.410662072125428e-9
# Global optimality certified with relative optimality gap 0.002528%!
# Global optimality certified with relative optimality gap 0.002528%!
# minimum(abs.(coefficients(polyGEXY))) = 0.00011032116607935466
# maximum(abs.(coefficients(polyGEXY))) = 63.52787985867283
#  status:GLOBAL runtime :5.008058768
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 13.925914136792265: 0.9999986959621564
# Processing time duration: 15.915330442048303
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 3.5638660353139633e-9
# Global optimality certified with relative optimality gap 0.002528%!
# Global optimality certified with relative optimality gap 0.002528%!
# minimum(abs.(coefficients(polyGEXY))) = 6.141407225785736e-5
# maximum(abs.(coefficients(polyGEXY))) = 64.32066206452723
#  status:GLOBAL runtime :5.885515471
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 15.915330442048303: 0.9999987212498489
# Processing time duration: 17.90474674730434
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.2737525187658611e-8
# Global optimality certified with relative optimality gap 0.002537%!
# Global optimality certified with relative optimality gap 0.002537%!
# minimum(abs.(coefficients(polyGEXY))) = 1.959420051023193e-6
# maximum(abs.(coefficients(polyGEXY))) = 64.79983187935642
#  status:GLOBAL runtime :6.496498651
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 17.90474674730434: 0.9999987444527987
# Processing time duration: 19.89416305256038
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.0350909122510518e-8
# Global optimality certified with relative optimality gap 0.002550%!
# Global optimality certified with relative optimality gap 0.002550%!
# minimum(abs.(coefficients(polyGEXY))) = 1.345260262213691e-5
# maximum(abs.(coefficients(polyGEXY))) = 65.09143489697067
#  status:GLOBAL runtime :7.501140734
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 19.89416305256038: 0.9999987561328376
# Processing time duration: 21.883579357816416
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 6.166096559537083e-9
# Global optimality certified with relative optimality gap 0.002569%!
# Global optimality certified with relative optimality gap 0.002569%!
# minimum(abs.(coefficients(polyGEXY))) = 1.772906925117323e-5
# maximum(abs.(coefficients(polyGEXY))) = 65.2676633220263
#  status:GLOBAL runtime :7.886409222
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.25133 and time duration 21.883579357816416: 0.9999987860338975
# γ =  0.79477
# Processing time duration: 0.6291128250940524
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.3235604163174893
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00026459.
# The relative optimality gap is: 32.329583%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00026459.
# The relative optimality gap is: 32.329583%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 4.8812336128875865e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00026459.
# The relative optimality gap is: 0.026458%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00026459.
# The relative optimality gap is: 0.026458%.
# minimum(abs.(coefficients(polyGEXY))) = 1.9563181668333482e-5
# maximum(abs.(coefficients(polyGEXY))) = 2.796040322263776
#  status:LOCAL/FAIL runtime :0.789284615
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 0.6291128250940524: 0.9998160336414857
# Processing time duration: 1.2582256501881048
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.2741760196912149e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00026008.
# The relative optimality gap is: 0.026006%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00026008.
# The relative optimality gap is: 0.026006%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.0760872757270912e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00026008.
# The relative optimality gap is: 0.026006%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00026008.
# The relative optimality gap is: 0.026006%.
# minimum(abs.(coefficients(polyGEXY))) = 0.00011860376605723073
# maximum(abs.(coefficients(polyGEXY))) = 4.704684769994358
#  status:LOCAL/FAIL runtime :1.63370404
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 1.2582256501881048: 0.9999588752975157
# Processing time duration: 1.8873384752821571
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.3132758354148775e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025820.
# The relative optimality gap is: 0.025819%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025820.
# The relative optimality gap is: 0.025819%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 9.468669643209206e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025820.
# The relative optimality gap is: 0.025819%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025820.
# The relative optimality gap is: 0.025819%.
# minimum(abs.(coefficients(polyGEXY))) = 8.003306232985945e-5
# maximum(abs.(coefficients(polyGEXY))) = 5.857047392056168
#  status:LOCAL/FAIL runtime :2.03475873
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 1.8873384752821571: 0.999980084216851
# Processing time duration: 2.5164513003762097
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.4782117437232917e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025766.
# The relative optimality gap is: 0.025764%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025766.
# The relative optimality gap is: 0.025764%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.8566912678143868e-10
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025766.
# The relative optimality gap is: 0.025766%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025766.
# The relative optimality gap is: 0.025766%.
# minimum(abs.(coefficients(polyGEXY))) = 8.850623680108943e-5
# maximum(abs.(coefficients(polyGEXY))) = 6.558699347091039
#  status:LOCAL/FAIL runtime :2.650735118
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 2.5164513003762097: 0.9999879573014202
# Processing time duration: 3.145564125470262
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 7.239786667525884e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025723.
# The relative optimality gap is: 0.025723%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025723.
# The relative optimality gap is: 0.025723%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.4012426803332754e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025723.
# The relative optimality gap is: 0.025722%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025723.
# The relative optimality gap is: 0.025722%.
# minimum(abs.(coefficients(polyGEXY))) = 1.6105091564219635e-5
# maximum(abs.(coefficients(polyGEXY))) = 6.983842700409994
#  status:LOCAL/FAIL runtime :3.343161272
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 3.145564125470262: 0.9999907846593277
# Processing time duration: 3.7746769505643143
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 9.847860414657305e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025709.
# The relative optimality gap is: 0.025708%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025709.
# The relative optimality gap is: 0.025708%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.4706277912336243e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025709.
# The relative optimality gap is: 0.025707%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025709.
# The relative optimality gap is: 0.025707%.
# minimum(abs.(coefficients(polyGEXY))) = 3.802226036587859e-5
# maximum(abs.(coefficients(polyGEXY))) = 7.24067929044456
#  status:LOCAL/FAIL runtime :4.136180486
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 3.7746769505643143: 0.9999921188431237
# Processing time duration: 4.403789775658367
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.2732431548538786
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025697.
# The relative optimality gap is: 27.298619%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025697.
# The relative optimality gap is: 27.298619%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.2085703567813674e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025697.
# The relative optimality gap is: 0.025696%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025697.
# The relative optimality gap is: 0.025696%.
# minimum(abs.(coefficients(polyGEXY))) = 1.4807302608142655e-5
# maximum(abs.(coefficients(polyGEXY))) = 7.397109505103083
#  status:LOCAL/FAIL runtime :4.626298673
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 4.403789775658367: 0.9999926564996358
# Processing time duration: 5.032902600752419
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 3.736283392854131e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025692.
# The relative optimality gap is: 0.025692%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025692.
# The relative optimality gap is: 0.025692%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 6.513707615556631e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025692.
# The relative optimality gap is: 0.025691%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025692.
# The relative optimality gap is: 0.025691%.
# minimum(abs.(coefficients(polyGEXY))) = 6.945469510292063e-6
# maximum(abs.(coefficients(polyGEXY))) = 7.49191168585044
#  status:LOCAL/FAIL runtime :5.102721799
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 5.032902600752419: 0.9999929825057463
# Processing time duration: 5.662015425846471
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.29901462884277996
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025689.
# The relative optimality gap is: 29.875774%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025689.
# The relative optimality gap is: 29.875774%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 5.649991807294695e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025689.
# The relative optimality gap is: 0.025688%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025689.
# The relative optimality gap is: 0.025688%.
# minimum(abs.(coefficients(polyGEXY))) = 2.6408615048907863e-5
# maximum(abs.(coefficients(polyGEXY))) = 7.549189464876312
#  status:LOCAL/FAIL runtime :5.664698839
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 5.662015425846471: 0.9999931707747554
# Processing time duration: 6.291128250940524
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 9.822868550801872e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025688.
# The relative optimality gap is: 0.025687%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025688.
# The relative optimality gap is: 0.025687%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.28900191140775683
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025688.
# The relative optimality gap is: 28.874503%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025688.
# The relative optimality gap is: 28.874503%.
# minimum(abs.(coefficients(polyGEXY))) = 1.6049831424058752e-6
# maximum(abs.(coefficients(polyGEXY))) = 7.584077202058657
#  status:LOCAL/FAIL runtime :6.197350203
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 6.291128250940524: 0.9999933009229776
# Processing time duration: 6.920241076034576
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 9.509537598273568e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025686%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025686%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 4.614247618080508e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025687%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025687%.
# minimum(abs.(coefficients(polyGEXY))) = 2.126266533599752e-5
# maximum(abs.(coefficients(polyGEXY))) = 7.605219721464558
#  status:LOCAL/FAIL runtime :6.851706939
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 6.920241076034576: 0.9999933634794007
# Processing time duration: 7.549353901128629
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 6.9961242547199515e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025686%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025686%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 5.489827863395409e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025686%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025686%.
# minimum(abs.(coefficients(polyGEXY))) = 2.8917846228935007e-6
# maximum(abs.(coefficients(polyGEXY))) = 7.617994512959309
#  status:LOCAL/FAIL runtime :7.357959986
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 7.549353901128629: 0.9999934193322988
# Processing time duration: 8.17846672622268
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 3.6521666268642707e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025687%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025687%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 3.205557571648408e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025687%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00025687.
# The relative optimality gap is: 0.025687%.
# minimum(abs.(coefficients(polyGEXY))) = 6.1997607184666765e-6
# maximum(abs.(coefficients(polyGEXY))) = 7.625776569624139
#  status:LOCAL/FAIL runtime :7.964395542
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 0.79477 and time duration 8.17846672622268: 0.9999934461998217
# γ =  2.5133
# Processing time duration: 0.1989416305256038
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.2394932972901627
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00301254.
# The relative optimality gap is: 23.648076%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00301254.
# The relative optimality gap is: 23.648076%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 9.51093509724536e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00301254.
# The relative optimality gap is: 0.301253%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00301254.
# The relative optimality gap is: 0.301253%.
# minimum(abs.(coefficients(polyGEXY))) = 2.6401025182649443e-5
# maximum(abs.(coefficients(polyGEXY))) = 0.3509475114740451
#  status:LOCAL/FAIL runtime :0.561523129
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 0.1989416305256038: 0.9972679427222104
# Processing time duration: 0.3978832610512076
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 7.45075600934821e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00279052.
# The relative optimality gap is: 0.279051%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00279052.
# The relative optimality gap is: 0.279051%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.30460528374914875
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00279052.
# The relative optimality gap is: 30.181477%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00279052.
# The relative optimality gap is: 30.181477%.
# minimum(abs.(coefficients(polyGEXY))) = 8.943547124856345e-6
# maximum(abs.(coefficients(polyGEXY))) = 0.656978198277146
#  status:LOCAL/FAIL runtime :0.998170642
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 0.3978832610512076: 0.999867421679936
# Processing time duration: 0.5968248915768113
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.2519345974075821
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00272604.
# The relative optimality gap is: 24.920855%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00272604.
# The relative optimality gap is: 24.920855%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.3204102820407142
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00272604.
# The relative optimality gap is: 31.768424%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00272604.
# The relative optimality gap is: 31.768424%.
# minimum(abs.(coefficients(polyGEXY))) = 7.778229690948857e-7
# maximum(abs.(coefficients(polyGEXY))) = 0.841128320913711
#  status:LOCAL/FAIL runtime :1.376595071
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 0.5968248915768113: 0.999937905291135
# Processing time duration: 0.7957665221024152
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 2.4953543697297e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00271741.
# The relative optimality gap is: 0.271741%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00271741.
# The relative optimality gap is: 0.271741%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.24499203211901605
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00271741.
# The relative optimality gap is: 24.227462%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00271741.
# The relative optimality gap is: 24.227462%.
# minimum(abs.(coefficients(polyGEXY))) = 5.915545034926547e-6
# maximum(abs.(coefficients(polyGEXY))) = 0.9524497403188064
#  status:LOCAL/FAIL runtime :1.693727149
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 0.7957665221024152: 0.9999467976063776
# Processing time duration: 0.9947081526280189
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 9.892918124268427e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00271484.
# The relative optimality gap is: 0.271483%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00271484.
# The relative optimality gap is: 0.271483%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 8.114559376250892e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00271484.
# The relative optimality gap is: 0.271483%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00271484.
# The relative optimality gap is: 0.271483%.
# minimum(abs.(coefficients(polyGEXY))) = 5.174629510182941e-5
# maximum(abs.(coefficients(polyGEXY))) = 1.0197297465990292
#  status:LOCAL/FAIL runtime :2.199274533
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 0.9947081526280189: 0.9999498384052883
# Processing time duration: 1.1936497831536226
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 5.5369943710588745e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270876.
# The relative optimality gap is: 0.270875%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270876.
# The relative optimality gap is: 0.270875%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 6.93323276397788e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270876.
# The relative optimality gap is: 0.270875%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270876.
# The relative optimality gap is: 0.270875%.
# minimum(abs.(coefficients(polyGEXY))) = 2.6720729033600448e-5
# maximum(abs.(coefficients(polyGEXY))) = 1.0604640426183485
#  status:LOCAL/FAIL runtime :2.588328798
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 1.1936497831536226: 0.9999520224854369
# Processing time duration: 1.3925914136792266
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 8.326129378771332e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270328.
# The relative optimality gap is: 0.270327%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270328.
# The relative optimality gap is: 0.270327%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 7.1516375396489575e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270328.
# The relative optimality gap is: 0.270327%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270328.
# The relative optimality gap is: 0.270327%.
# minimum(abs.(coefficients(polyGEXY))) = 3.2100820865728988e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.0852662802017379
#  status:LOCAL/FAIL runtime :2.912798279
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 1.3925914136792266: 0.9999536049294533
# Processing time duration: 1.5915330442048303
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 7.11159031446106e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270168.
# The relative optimality gap is: 0.270168%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270168.
# The relative optimality gap is: 0.270168%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.0845844152028325e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270168.
# The relative optimality gap is: 0.270167%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270168.
# The relative optimality gap is: 0.270167%.
# minimum(abs.(coefficients(polyGEXY))) = 2.035447460706195e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.100165705972977
#  status:LOCAL/FAIL runtime :3.201023272
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 1.5915330442048303: 0.9999540714241385
# Processing time duration: 1.790474674730434
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 4.204947044964244e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270279.
# The relative optimality gap is: 0.270278%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270279.
# The relative optimality gap is: 0.270278%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 5.637615264643475e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270279.
# The relative optimality gap is: 0.270278%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270279.
# The relative optimality gap is: 0.270278%.
# minimum(abs.(coefficients(polyGEXY))) = 2.3222975767752624e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.1092089169645876
#  status:LOCAL/FAIL runtime :3.820294125
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 1.790474674730434: 0.9999541720665976
# Processing time duration: 1.9894163052560379
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 9.716533256745816e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270392.
# The relative optimality gap is: 0.270391%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270392.
# The relative optimality gap is: 0.270391%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 2.8220764300170675e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270392.
# The relative optimality gap is: 0.270391%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270392.
# The relative optimality gap is: 0.270391%.
# minimum(abs.(coefficients(polyGEXY))) = 1.882202538728006e-5
# maximum(abs.(coefficients(polyGEXY))) = 1.1146887214644505
#  status:LOCAL/FAIL runtime :3.992233572
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 1.9894163052560379: 0.9999541652032893
# Processing time duration: 2.1883579357816414
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.3598814754085307e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270417.
# The relative optimality gap is: 0.270416%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270417.
# The relative optimality gap is: 0.270416%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 5.4479856258391054e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270417.
# The relative optimality gap is: 0.270416%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270417.
# The relative optimality gap is: 0.270416%.
# minimum(abs.(coefficients(polyGEXY))) = 5.142754767439906e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.1180122007347335
#  status:LOCAL/FAIL runtime :4.428736197
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 2.1883579357816414: 0.9999541244840209
# Processing time duration: 2.387299566307245
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.5677489060547358e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270421.
# The relative optimality gap is: 0.270421%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270421.
# The relative optimality gap is: 0.270421%.
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.6581058805085012e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270421.
# The relative optimality gap is: 0.270421%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270421.
# The relative optimality gap is: 0.270421%.
# minimum(abs.(coefficients(polyGEXY))) = 1.4484400136352321e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.1200280581439124
#  status:LOCAL/FAIL runtime :4.90722583
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 2.5133 and time duration 2.387299566307245: 0.9999540385680186
# Processing time duration: 2.5862411968328494
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: NO_SOLUTION
# optimum = 1.3444206141291437e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270472.
# The relative optimality gap is: 0.270470%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00270472.
# ...
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: FEASIBLE_POINT
# optimum = 0.8232226050813859
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.82280333.
# The relative optimality gap is: 0.041928%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.82280333.
# The relative optimality gap is: 0.041928%.
# optimum = 0.823283216133583
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.82280333.
# The relative optimality gap is: 0.047989%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.82280333.
# The relative optimality gap is: 0.047989%.
# minimum(abs.(coefficients(polyGEXY))) = 2.5656669553837432e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.037262667607803064
#  status:LOCAL/FAIL runtime :1.78482036
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.03382007718935264: 0.9659505214777444
# Processing time duration: 0.03580949349460868
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: FEASIBLE_POINT
# optimum = 0.8314544706770929
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.83105234.
# The relative optimality gap is: 0.040213%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.83105234.
# The relative optimality gap is: 0.040213%.
# termination status: SLOW_PROGRESS
# solution status: FEASIBLE_POINT
# optimum = 0.8314362519459513
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.83105234.
# The relative optimality gap is: 0.038391%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.83105234.
# The relative optimality gap is: 0.038391%.
# minimum(abs.(coefficients(polyGEXY))) = 2.5774190495840267e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726409949867905
#  status:LOCAL/FAIL runtime :1.931458543
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.03580949349460868: 0.9647363323966686
# Processing time duration: 0.037798909799864715
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8387593111952457
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.83841794.
# The relative optimality gap is: 0.034137%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.83841794.
# The relative optimality gap is: 0.034137%.
# termination status: SLOW_PROGRESS
# solution status: FEASIBLE_POINT
# optimum = 0.8387213031503766
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.83841794.
# The relative optimality gap is: 0.030336%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.83841794.
# The relative optimality gap is: 0.030336%.
# minimum(abs.(coefficients(polyGEXY))) = 2.609535800148182e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726526519355919
#  status:LOCAL/FAIL runtime :1.992323628
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.037798909799864715: 0.9641245005518544
# Processing time duration: 0.03978832610512076
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: FEASIBLE_POINT
# optimum = 0.845612926230809
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.84534380.
# The relative optimality gap is: 0.026913%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.84534380.
# The relative optimality gap is: 0.026913%.
# optimum = 0.8456898930906734
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.84534380.
# The relative optimality gap is: 0.034609%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.84534380.
# The relative optimality gap is: 0.034609%.
# minimum(abs.(coefficients(polyGEXY))) = 2.6540592129084487e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726617037051162
#  status:LOCAL/FAIL runtime :2.074815304
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.03978832610512076: 0.9634912192483247
# Processing time duration: 0.041777742410376795
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: FEASIBLE_POINT
# optimum = 0.8520033275794257
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.85170902.
# The relative optimality gap is: 0.029431%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.85170902.
# The relative optimality gap is: 0.029431%.
# termination status: SLOW_PROGRESS
# solution status: FEASIBLE_POINT
# optimum = 0.8519968163917128
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.85170902.
# The relative optimality gap is: 0.028780%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.85170902.
# The relative optimality gap is: 0.028780%.
# minimum(abs.(coefficients(polyGEXY))) = 2.7052581635843857e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.037266899326847666
#  status:LOCAL/FAIL runtime :2.175633367
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.041777742410376795: 0.9627041897123392
# Processing time duration: 0.04376715871563283
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8578064133054573
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.85758394.
# The relative optimality gap is: 0.022248%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.85758394.
# The relative optimality gap is: 0.022248%.
# termination status: SLOW_PROGRESS
# solution status: FEASIBLE_POINT
# optimum = 0.8577360874796752
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.85758394.
# The relative optimality gap is: 0.015215%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.85758394.
# The relative optimality gap is: 0.015215%.
# minimum(abs.(coefficients(polyGEXY))) = 2.7573665779903556e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726746818767818
#  status:LOCAL/FAIL runtime :2.277541482
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.04376715871563283: 0.9618157674535367
# Processing time duration: 0.04575657502088887
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8630913723093127
# Global optimality certified with relative optimality gap 0.008173%!
# Global optimality certified with relative optimality gap 0.008173%!
# minimum(abs.(coefficients(polyGEXY))) = 2.8082918065766796e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726788419331954
#  status:GLOBAL runtime :2.190591562
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.04575657502088887: 0.960932703812495
# Processing time duration: 0.047745991326144904
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: FEASIBLE_POINT
# optimum = 0.8680027688818064
# Global optimality certified with relative optimality gap 0.008207%!
# Global optimality certified with relative optimality gap 0.008207%!
# minimum(abs.(coefficients(polyGEXY))) = 2.855524082350639e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.037268206847692546
#  status:GLOBAL runtime :2.513851903
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.047745991326144904: 0.9599753103851935
# Processing time duration: 0.04973540763140095
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8726066197819706
# Global optimality certified with relative optimality gap 0.000122%!
# Global optimality certified with relative optimality gap 0.000122%!
# minimum(abs.(coefficients(polyGEXY))) = 2.899612565241333e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726845798582611
#  status:GLOBAL runtime :2.408596705
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.04973540763140095: 0.9592091515125505
# Processing time duration: 0.051724823936656984
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8770292811936874
# Global optimality certified with relative optimality gap 0.006198%!
# Global optimality certified with relative optimality gap 0.006198%!
# minimum(abs.(coefficients(polyGEXY))) = 2.9398131608173843e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726864827828231
#  status:GLOBAL runtime :2.448844194
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.051724823936656984: 0.9583492922235606
# Processing time duration: 0.05371424024191302
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8810432649629868
# Global optimality certified with relative optimality gap 0.000052%!
# Global optimality certified with relative optimality gap 0.000052%!
# minimum(abs.(coefficients(polyGEXY))) = 2.9757765745517318e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726879822798611
#  status:GLOBAL runtime :2.56178904
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.05371424024191302: 0.9574989540952599
# Processing time duration: 0.05570365654716906
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8848550937192367
# Global optimality certified with relative optimality gap 0.000043%!
# Global optimality certified with relative optimality gap 0.000043%!
# minimum(abs.(coefficients(polyGEXY))) = 3.0072554577710752e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726891042801075
#  status:GLOBAL runtime :2.632532209
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.05570365654716906: 0.9566588052023046
# Processing time duration: 0.057693072852425094
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8883427401189519
# Global optimality certified with relative optimality gap 0.000085%!
# Global optimality certified with relative optimality gap 0.000085%!
# minimum(abs.(coefficients(polyGEXY))) = 3.0346444432166346e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.037268995296439754
#  status:GLOBAL runtime :2.699042455
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.057693072852425094: 0.9558504409124611
# Processing time duration: 0.05968248915768113
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8917068270133168
# Global optimality certified with relative optimality gap 0.000047%!
# Global optimality certified with relative optimality gap 0.000047%!
# minimum(abs.(coefficients(polyGEXY))) = 3.059158268489124e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.0372690639516831
#  status:GLOBAL runtime :2.821556115
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.05968248915768113: 0.955032190940547
# Processing time duration: 0.061671905462937174
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8948724523424211
# Global optimality certified with relative optimality gap 0.000045%!
# Global optimality certified with relative optimality gap 0.000045%!
# minimum(abs.(coefficients(polyGEXY))) = 3.080354110403461e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726911718994345
#  status:GLOBAL runtime :2.874067298
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.061671905462937174: 0.9542258903980141
# Processing time duration: 0.06366132176819321
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [3, 2]
# [2, 1]
# -----------------------------------------------------------------------------
# optimum = 0.8978575494542469
# Global optimality certified with relative optimality gap 0.000041%!
# Global optimality certified with relative optimality gap 0.000041%!
# minimum(abs.(coefficients(polyGEXY))) = 3.0991792645335156e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.037269158894470966
#  status:GLOBAL runtime :2.988543262
# Processing states: D1 D2 D3 D4 D5 D6 D7 D8 D9 D10 Median fidelity for γ = 251.33 and time duration 0.06366132176819321: 0.9534314761306322
# MULT_LINDBLAD_CONSTR_TSSOS_threshold_1e-15_FROB_QO_2024-Sep-29_at_21-07.h5

# %%
println(tests_data_file_name)
# Out:
# MULT_LINDBLAD_CONSTR_TSSOS_threshold_1e-15_FROB_QO_2024-Sep-29_at_21-07.h5
