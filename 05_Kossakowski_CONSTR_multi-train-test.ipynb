# %% [markdown]
# # Identification of Kossakowski form Markovian ME
# ## (for spin-boson system using TSSOS POP method)

# %%
include("LiPoSID.jl")

using QuantumOptics
basis = NLevelBasis(2)
using LinearAlgebra

using HDF5
using DynamicPolynomials

using Dates

using Statistics

using TSSOS

# %% [markdown]
# In this notebook we identify and test accuracy of Markovian master equations in Kossakowski form for the nontrivial example of the data generated by the full-featured simulation of the spin-boson model (two-level system coupled with the bath of the continuum of the harmonic oscillators).

# %% [markdown]
# According to the theorem proven by Kossakowski (Kossakowski, 1973) Markovian master equation could be rewritten for a two-level system $\rho \in M(2)$ as follows:
#
# $
#    \mathcal{K} = -i[H,\rho] + \frac{1}{2} \sum_{i,j}^3 C_{ij} \{[f_i, \rho f_j] + [f_i\rho, f_j]\},
# $
# where

# %% [markdown]
# $
# \text{(i)} \quad \quad
#            f_i f_j = \frac{1}{4}\delta_{ij}I  +\frac{i}{2} \sum_{k=1}^3 \epsilon_{ijk} f_k \\ \text{which means:} \notag \\ \quad
#     \operatorname{Tr}(f_i f_j)=\frac{1}{2}\delta_{ij}, \quad \operatorname{Tr}(f_i) = 0 \notag
# $
#
#
# and we can choose basis operators $f_i$ as halfs of Pauli matrices
# $\{ \sigma_x, \sigma_y, \sigma_z \}$:
#
# $
#     f_1 = \sigma_x/2  =
#     \begin{pmatrix}
#         0 & 1 \\ 1 & 0
#     \end{pmatrix} / 2 \\
#     f_2 = \sigma_y/2  = \begin{pmatrix}
#         0 & i \\ -i & 0
#     \end{pmatrix} / 2\\
#     f_3 = \sigma_z/2 = \begin{pmatrix}
#         1 & 0 \\ 0 & -1
#     \end{pmatrix} / 2
# $

# %%
σˣ = [ 0 1 
       1 0 ]

σʸ = [ 0.   im*1
      -im*1 0    ]

σᶻ = [ 1.  0
       0  -1 ] 

fᴷ₁ = σˣ/2; fᴷ₂ = σʸ/2; fᴷ₃ = σᶻ/2

@assert tr(σˣ/2*σʸ/2) == tr(σˣ/2*σᶻ/2) ==  tr(σʸ/2*σᶻ/2) ≈ 0
@assert tr(σˣ/2*σˣ/2) == tr(σʸ/2*σʸ/2) == tr(σᶻ/2*σᶻ/2) ≈ 1/2

fᴷᴼᴺᴮ = [fᴷ₁, fᴷ₂, fᴷ₃]
# Out:
# 3-element Vector{Matrix{ComplexF64}}:
#  [0.0 + 0.0im 0.5 + 0.0im; 0.5 + 0.0im 0.0 + 0.0im]
#  [0.0 + 0.0im 0.0 + 0.5im; 0.0 - 0.5im 0.0 + 0.0im]
#  [0.5 + 0.0im 0.0 + 0.0im; 0.0 + 0.0im -0.5 + 0.0im]

# %% [markdown]
# $
#      \text{(ii)} \quad \quad \quad
#      H = \sum_1^3 h_i f_i, \quad h_i \in \mathbb{R}
# $
#
# which means we can use Hamiltonian of the form:
#
# $
# H = \begin{pmatrix}
# h_3   & h_1 + i h_2          \\
# h_1 - i h_2 & -h_3
# \end{pmatrix} / 2
# $

# %%
@polyvar ϵ h₁ h₂ 

Hˢʸᵐᵇ = [ ϵ           h₁+im*h₂
           h₁-im*h₂   -ϵ            ] / 2

Hᴷˢʸᵐᵇ = h₁ * fᴷ₁ + h₂ * fᴷ₂  + ϵ * fᴷ₃ 

@assert tr(Hᴷˢʸᵐᵇ) == 0
@assert Hᴷˢʸᵐᵇ == Hˢʸᵐᵇ

# %% [markdown]
# $
#      \text{(iii)} \quad \{C_{ij}\} = \begin{pmatrix}
# \gamma - 2\gamma_1    & - i a_3            &  i a_2 \\
# i a_3                 & \gamma - 2\gamma_2 & -i a_1 \\
# -i a_2                & i a_1              & \gamma - 2\gamma_3
# \end{pmatrix}
# =  \begin{pmatrix}
# \kappa_1   & - i a_3    &  i a_2 \\
# i a_3       & \kappa_2   & -i a_1 \\
# -i a_2      & i a_1      & \kappa_3
# \end{pmatrix}
# $

# %%
@polyvar κ[1:3]; κ₁,κ₂,κ₃ = κ[1],κ[2],κ[3]
@polyvar a[1:3]; a₁,a₂,a₃ = a[1],a[2],a[3]

Cˢʸᵐᵇ = [  κ[1]     -im*a[3]     im*a[2]
           im*a[3]   κ[2]       -im*a[1] 
          -im*a[2]   im*a[1]     κ[3]     ] ;

# %% [markdown]
# $
#     \text{(iv)} \quad \quad \quad \quad \gamma_1, \gamma_2, \gamma_3 \geq 0
# $

# %% [markdown]
# If $\gamma = 0$ the evolution is just unitary, and in case $\gamma >0 $ <br>
# in order for the evolution to be completely positive it is nessesary and sufficient that <br>
# (denoting $\kappa_i = \gamma - 2 \gamma_i$):
#
# $
#     \kappa_1 + \kappa_2 + \kappa_3 \geq 0 \\
# \kappa_1 \kappa_2  + \kappa_3 \kappa_1  + \kappa_1 \kappa_2  \geq a_1^2 + a_2^2 + a_3^2 \\
#    \kappa_1 \kappa_2 \kappa_3 \geq  \kappa_1 a_1^2 + \kappa_2 a_2^2 + \kappa_3 a_3^2
# $

# %%
constr1 = κ₁ + κ₂ + κ₃ 
constr2 = κ₁*κ₂ + κ₃*κ₁ + κ₂*κ₃ - - a₁^2 - a₂^2 - a₃^2
constr3 = κ₁*κ₂*κ₃ - κ₁*a₁^2 - κ₂*a₂^2 - κ₃*a₃^2

constraints = [ ϵ, κ₁, κ₂, κ₃, constr1, constr2, constr3]
# Out:
# 7-element Vector{Polynomial{true, Int64}}:
#  ϵ
#  κ₁
#  κ₂
#  κ₃
#  κ₁ + κ₂ + κ₃
#  κ₁κ₂ + κ₁κ₃ + κ₂κ₃ + a₁² - a₂² - a₃²
#  κ₁κ₂κ₃ - κ₁a₁² - κ₂a₂² - κ₃a₃²

# %% [markdown]
# To ensure the objective is polynomial we can write loss function with double step and using the Frobenius norm :
#
# $ L = \sum_{j=3}^N
# {\left\| \rho_j - \rho_{j-2} - {\mathcal{L}} \left[\int^{t_j}_{t_{j-2}}\rho(t)dt \right] \right\| }^2_F $
#
# and apply the Simpson approximation method to evaluate the integral:
#
# $
# \int^{t_j}_{t_{j-2}}\rho(t)dt = \frac{1}{3} \Delta t \left[ \rho_{j-2} + 4 \rho_{j-1} + \rho_j \right] +  \mathcal{O}(\Delta t^5).$

# %% [markdown]
# Using it we can calculate objective as polynomial of nine variables  and cast the optimization problem:
#
# $
# \min L\left( h_1, h_2, h_3,\kappa_1,\kappa_2, \kappa_3, a_1, a_2, a_3, \{\rho_k\} \right)
# $
#
# which is subject to one linear and two polynomial constraints above.
#
# In this way we obtain constraint polynomial optimization problem that can be easily and naturally solved with TSSOS library.
#
# Below is the function `kossak_obj()`that implements assembling of the objective from the time series of density matrices $\{\rho_k\}$ at moments of time $\{\rho_i\}$.

# %%
function kossak_obj(ρ, t, Hˢʸᵐᵇ, Cˢʸᵐᵇ, Fᴼᴺᴮ)

    function Dc(ρ, t)
        U = (Hˢʸᵐᵇ*ρ - ρ*Hˢʸᵐᵇ)/im 
        D = sum(Cˢʸᵐᵇ .* [2*fᵢ*ρ*fⱼ' - ρ*fⱼ'*fᵢ - fⱼ'*fᵢ*ρ  for fᵢ in Fᴼᴺᴮ, fⱼ in Fᴼᴺᴮ])/2
        return U + D
    end 

    obj = 0
    for i in 3:length(ρ)
        obj += LiPoSID.frobenius_norm2(
            ρ[i] - ρ[i-2] - (t[i]-t[i-1])*(Dc(ρ[i], t[i])+
            4*Dc(ρ[i-1], t[i-1])+Dc(ρ[i-2], t[i-2]))/3
        )
    end

    if isempty(monomials(obj))
        obj = 0. 
    else
        obj = sum(real(coef) * mon for (coef, mon) in zip(coefficients(obj), monomials(obj)))
    end

    return obj

end
# Out:
# kossak_obj (generic function with 1 method)

# %% [markdown]
# Density matrices for four bases initial states $\ket{0}$, $\ket{1}$, $\ket{x}$, $\ket{y}$ that were used to simulate training data are defined as follows:
# \begin{align}
#    \rho^{(g)}_0 &=  \rho^{\ket{0}}_0 = \left(
# \begin{array}{c}
#             1  \\
#             0   \\
#         \end{array}
#                 \right)
#                 \left(
#                 \begin{array} {cc}
#                 1 & 0
#                 \end{array}
#                 \right) =
# \ket{0} \bra{0} = \left(
#         \begin{array}{ccccc}
#             1  &  0  \\
#             0  &  0   \\
#         \end{array}
#             \right),\\
# \rho^{(e)}_0 &=\rho^{\ket{1}}_0 =\ket{1} \bra{1} =
# \begin{pmatrix}
# 0 \\ 1
# \end{pmatrix}
# \begin{pmatrix}
# 0 & 1
# \end{pmatrix}=
# \left(
#         \begin{array}{ccccc}
#             0  &  0  \\
#             0  &  1  \\
#         \end{array}
#             \right), \notag\\
# \rho^{\ket{x}}_0 &=\ket{x} \bra{x} = |+\rangle \langle + | = \left(
# \begin{array}{c}
#             1/\sqrt{2}  \\
#             1/\sqrt{2}   \\
#         \end{array}
#                 \right)
#                 \left(
#                 \begin{array} {cc}
#                 1/\sqrt{2} & 1/\sqrt{2}
#                 \end{array}
#                 \right) = \frac{1}{2}\left(
#         \begin{array}{ccccc}
#             1  &  1  \\
#             1  &  1   \\
#         \end{array}
#     \right), \notag\\
# \rho^{\ket{y}}_0  &= \ket{y} \bra{y} = |-\rangle \langle-| = \left(
# \begin{array}{c}
#             1/\sqrt{2}  \\
#             i/\sqrt{2}   \\
#         \end{array}
#                 \right)
#                 \left(
#                 \begin{array} {cc}
#                 1/\sqrt{2} & -i/\sqrt{2}
#                 \end{array}
#                 \right) = \frac{1}{2}\left(
#         \begin{array}{ccccc}
#             1  &  -i  \\
#             i  &  1   \\
#         \end{array}
#     \right)
# \end{align}
#
# The function `kossak_GEXY_obj()`
# below combines the objective for the for data series of density matrices starting in four basis states
# $\ket{0}$, $\ket{1}$, $\ket{x}$, $\ket{y}$:

# %%
function kossak_GEXY_obj(ρᵍᵉˣʸ, tᵍᵉˣʸ, H0ˢʸᵐᵇ, Cˢʸᵐᵇ, fᴼᴺᴮ)

    ρᵍ, ρᵉ, ρˣ, ρʸ = ρᵍᵉˣʸ
    tᵍ, tᵉ, tˣ, tʸ = tᵍᵉˣʸ

    polyG = kossak_obj(ρᵍ, tᵍ, H0ˢʸᵐᵇ, Cˢʸᵐᵇ, fᴼᴺᴮ)
    polyE = kossak_obj(ρᵉ, tᵉ, H0ˢʸᵐᵇ, Cˢʸᵐᵇ, fᴼᴺᴮ)
    polyX = kossak_obj(ρˣ, tˣ, H0ˢʸᵐᵇ, Cˢʸᵐᵇ, fᴼᴺᴮ)
    polyY = kossak_obj(ρʸ, tʸ, H0ˢʸᵐᵇ, Cˢʸᵐᵇ, fᴼᴺᴮ)

    polyGEXY = polyG + polyE + polyX + polyY

    return polyGEXY
end
# Out:
# kossak_GEXY_obj (generic function with 1 method)

# %% [markdown]
# ### References
#
# 1. Kossakowski, Bull. Acad. Pol. Sci. Ser. Math. Astr. Phys. 21, 649 (1973)
#
# 2. Completely positive dynamical semigroups of Nlevel systems
# Vittorio Gorini, Andrzej Kossakowski, and E. C. G. Sudarshan
# Citation: J. Math. Phys. 17, 821 (1976); doi: 10.1063/1.522979

# %%
# Here we set parameters what data to use for training and testing

evol_data_file_name = "DATA/ALL_GAMMAS_B4_D10.h5"

tests_dir = ""

ρᵍ₀ = [ 1 0
        0 0 ]    # state to measure initial distance from

dodeca_10_states = ["D"*string(n) for n=1:10];
basis_states = ["B"*string(n) for n=1:4];

train_states = basis_states 
test_states = dodeca_10_states

all_states = vcat(train_states, test_states);

# %% [markdown]
# Checking functions on one particular coupling level

# %%
γᵢ = "0.25133"

tᵍᵉˣʸ , ρᵍᵉˣʸ  = LiPoSID.read_GEXY_timeevolution(evol_data_file_name, γᵢ)
polyGEXYfull = kossak_GEXY_obj(ρᵍᵉˣʸ, tᵍᵉˣʸ, Hˢʸᵐᵇ, Cˢʸᵐᵇ, fᴷᴼᴺᴮ)
# Out:
# 0.10341163322607885ϵ² - 4.104630886766538e-5ϵh₁ + 3.451755329501592e-5ϵh₂ - 0.0002589838118092574ϵκ₁ + 0.0002589838118092574ϵκ₂ + 0.0012450858989678402ϵa₁ - 0.0008044950814777315ϵa₂ + 1.0519096548020683h₁² + 0.0005179676236185148h₁h₂ + 5.432584669112943e-20h₁κ₁ - 1.725877664750785e-5h₁κ₂ + 1.725877664750796e-5h₁κ₃ - 2.1131584754297306h₁a₂ - 0.0012450858989678404h₁a₃ + 1.0518715157602614h₂² - 2.052315443383269e-5h₂κ₁ - 3.3868128414917834e-20h₂κ₂ + 2.052315443383269e-5h₂κ₃ + 2.1131584754297306h₂a₁ + 0.0008044950814777305h₂a₃ + 0.2629774137005171κ₁² + 0.5000923843340622κ₁κ₂ + 0.025862443066971434κ₁κ₃ - 0.0006225429494839201κ₁a₂ + 1.0565792377148653κ₁a₃ + 0.26296787894006535κ₂² + 0.02584337354606811κ₂κ₃ - 0.00040224754073886574κ₂a₁ + 1.0565792377148653κ₂a₃ + 0.025852908306519713κ₃² - 0.00040224754073886574κ₃a₁ - 0.0006225429494839201κ₃a₂ + 1.269688888901564a₁² - 8.005395128533376e-37a₁a₂ - 4.658513032068184e-37a₁a₃ + 1.269688888901564a₂² + 4.647304221135261e-36a₂a₃ + 1.269688888901564a₃² - 5.199679015672933ϵ + 0.00013669789552729324h₁ - 0.00035392288736811996h₂ + 0.006915807400816533κ₁ + 0.006896966595444998κ₂ - 0.012998820971026752κ₃ - 0.0312922847698259a₁ + 0.021015710332322916a₂ + 0.10545437422858547a₃ + 65.37495321955478

# %%
variables(polyGEXYfull)'
# Out:
# 1×9 adjoint(::Vector{PolyVar{true}}) with eltype PolyVar{true}:
#  ϵ  h₁  h₂  κ₁  κ₂  κ₃  a₁  a₂  a₃

# %%
LiPoSID.coefficient_range(polyGEXYfull)
# Out:
# 7.125837652874591e-39

# %% [markdown]
# Below is the wrapper function to call the TSSOS library function for the constraint polynomial optimization:

# %%
function min_cs_tssos(p, constrs)

    coeffs = coefficients(p)
    reg_coef = 0

    pop =[p+reg_coef*sum(variables(p).^2), constrs...] ./ maximum(abs.(coeffs))

    d = maxdegree(p)
    
    # Initial optimization step
    opt, sol, data = cs_tssos_first(pop, variables(pop), d; solution=true, QUIET=true)
    ref_sol, flag = TSSOS.refine_sol(opt, sol, data; QUIET=true)
    prev_opt, prev_sol, prev_data = opt, sol, data 

    # Check if the solution needs further refinement
    if flag != 0
        while ~isnothing(sol) && flag != 0
            prev_opt, prev_sol, prev_data = opt, sol, data
            opt, sol, data = cs_tssos_higher!(data; solution=true, QUIET=true) 
        end
        ref_sol, flag = TSSOS.refine_sol(prev_opt, prev_sol, prev_data; QUIET=true)
    end

    solution = variables(p) => ref_sol

    if flag == 0 
        status_name = "GLOBAL"
    else
        status_name = "LOCAL/FAIL"
    end

    return solution, status_name

end
# Out:
# min_cs_tssos (generic function with 1 method)

# %%
sol, st = min_cs_tssos(polyGEXYfull, constraints)
# Out:
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.694092738736601e-6
# Global optimality certified with relative optimality gap 0.000032%!
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Global optimality certified with relative optimality gap 0.000951%!
# (PolyVar{true}[ϵ, h₁, h₂, κ₁, κ₂, κ₃, a₁, a₂, a₃] => [25.140907362543857, 0.000276938268486056, -0.00016636574463716887, 0.3583550700151173, 0.18237860441852494, 0.0010986066520666368, 2.3612851882529155e-5, 1.8519677711058513e-6, -0.2568046278558424], "GLOBAL")

# %%
Cˢⁱᵈ = convert.(ComplexF64,subs(Cˢʸᵐᵇ, sol))
Cˢⁱᵈ[1:2,1:2]
# Out:
# 2×2 Matrix{ComplexF64}:
#  0.358355+0.0im            0.0+0.256805im
#       0.0-0.256805im  0.182379+0.0im

# %%
sol, st = min_cs_tssos(LiPoSID.filter_odd_terms_by_relative_threshold(polyGEXYfull, 1e-4), constraints)
# Out:
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [6, 2, 1]
# [1, 2, 1]
# -----------------------------------------------------------------------------
# optimum = 6.238006900811503e-8
# Global optimality certified with relative optimality gap 0.000011%!
# Global optimality certified with relative optimality gap 0.001181%!
# (PolyVar{true}[ϵ, h₁, h₂, κ₁, κ₂, κ₃, a₁, a₂, a₃] => [25.140687057273993, -0.026750789681977468, -0.040394886607506224, 0.25022355504390975, 0.2577643397234901, 0.08926101924096891, 0.04021490209924806, -0.02663256378282678, -0.2406725416178681], "GLOBAL")

# %%
st
# Out:
# "GLOBAL"

# %%
Cˢⁱᵈ = convert.(ComplexF64,subs(Cˢʸᵐᵇ, sol))
Cˢⁱᵈ[1:2,1:2]
# Out:
# 2×2 Matrix{ComplexF64}:
#  0.250224+0.0im            0.0+0.240673im
#       0.0-0.240673im  0.257764+0.0im

# %%
Hˢⁱᵈ = convert.(ComplexF64, subs(Hˢʸᵐᵇ, sol))
# Out:
# 2×2 Matrix{ComplexF64}:
#     12.5703+0.0im        -0.0133754-0.0201974im
#  -0.0133754+0.0201974im    -12.5703+0.0im

# %% [markdown]
# Below we perform system identification and testing of the accuracy of identified models for all available coupling levels of spin boson system:

# %%
println(" MULTI DURATION SYSTEM IDENTIFICATION w CONSTRAINED TSSOS and KOSSAKOWSKI Frobenius objective QO simulation")

γ = [ "0.079477",  "0.25133", "0.79477", "2.5133", "7.9477", "25.133", "79.477", "251.33"]

date_and_time_string = string(Dates.format(now(), "yyyy-u-dd_at_HH-MM"))

evol_data_file_name = "DATA/ALL_GAMMAS_B4_D10.h5"

relative_threshold = 1e-15

rltrs = string(convert(Int, floor(log10(relative_threshold))))

tests_data_file_name = "MULT_KOSSAK_CONSTR_TSSOS_threshold_1e"*rltrs*"_FROB_QO_"*date_and_time_string * ".h5"

FminGammas = []
FmedianGammas = []
FmeanGammas = []
Epsilons = []
CoefRanges = []

for γᵢ in γ
    println("γ =  "*γᵢ)

    # Save results into HDF5
    h5open(tests_dir*tests_data_file_name,"cw") do fid
        γ_group = create_group(fid, γᵢ) # Create gamma coupling group
    end
    
    # Read time series data for the current γ
    tᵍᵉˣʸ, ρᵍᵉˣʸ = LiPoSID.read_GEXY_timeevolution(evol_data_file_name, γᵢ)
    tᵍ, tᵉ, tˣ, tʸ = tᵍᵉˣʸ
    
    # Find the end of the shortest time series
    t_end = minimum([tᵍ[end], tᵉ[end], tˣ[end], tʸ[end]])

    # Dynamically generate the duration steps
    max_steps = Int(floor(t_end * 2 * parse(Float64, γᵢ)))  # Maximum steps based on t_end and γᵢ
    duration_steps = [i/(2*parse(Float64, γᵢ)) for i in 1:max_steps]  # Generates dynamic steps up to t_end
    
    # Ensure steps do not exceed the shortest time series
    duration_steps = duration_steps[duration_steps .<= t_end]

    for t_duration in duration_steps
        println("Processing time duration: ", t_duration)

        elapsed_time = @timed begin
            # Masking the time series up to t_duration
            t_masked = [t[t .<= t_duration] for t in [tᵍ, tᵉ, tˣ, tʸ]]
            min_length = minimum(length.(t_masked))  # Ensure all time series are truncated to the same length
            t_masked = [t[1:min_length] for t in t_masked]

            ρ_masked = [ρ[1:min_length] for ρ in ρᵍᵉˣʸ] # Truncate ρᵍᵉˣʸ accordingly

            # Objective function construction and minimization
            polyGEXYfull = kossak_GEXY_obj(ρ_masked, t_masked, Hˢʸᵐᵇ, Cˢʸᵐᵇ, fᴷᴼᴺᴮ)
            polyGEXY = LiPoSID.filter_odd_terms_by_relative_threshold(polyGEXYfull, relative_threshold)
            sol, status = min_cs_tssos(polyGEXY, constraints)
        end

        @show minimum(abs.(coefficients(polyGEXY)))
        @show maximum(abs.(coefficients(polyGEXY)))
        push!(CoefRanges, LiPoSID.coefficient_range(polyGEXYfull))

        print(" status:", status)
        print(" runtime :", elapsed_time.time)

        Hˢⁱᵈ = convert.(ComplexF64, subs(Hˢʸᵐᵇ, sol))
        Cˢⁱᵈ = convert.(ComplexF64, subs(Cˢʸᵐᵇ, sol))
        epsilon = subs(ϵ, sol)
        push!(Epsilons, epsilon)

        # Save results into HDF5
        h5open(tests_dir*tests_data_file_name,"cw") do fid
            γ_group = open_group(fid, γᵢ) # Create gamma coupling group
            t_group = create_group(γ_group, string(t_duration)) # Create time duration group
            t_group["epsilon"] = convert(Float64, epsilon)
            t_group["H"] = convert.(ComplexF64, Hˢⁱᵈ)
            t_group["C"] = convert.(ComplexF64, Cˢⁱᵈ)
            t_group["status"] = status
            t_group["runtime"] = elapsed_time.time
        end

        println()

        FminStates = []
        FmedianStates = []
        FmeanStates = []

        print("Processing states: ")

        for state in test_states # Loop over initial states
            print(state*" ")
            start_time = time()

            tₛ, ρₛ = LiPoSID.read_timeevolution(evol_data_file_name, state, γᵢ)
            ρₛ = convert(Vector{Matrix{ComplexF64}}, ρₛ)
            ρᵗˢᵗ = [DenseOperator(basis, Hermitian(ρₜ)) for ρₜ in ρₛ]
            tᵗˢᵗ = convert(Vector{Float64}, tₛ)

            ρₒ = DenseOperator(basis, ρₛ[1])
            dt = tᵗˢᵗ[2] - tᵗˢᵗ[1]
            tᵉⁿᵈ = tᵗˢᵗ[end]

            effective_Lindblad = LiPoSID.get_lindblad_operators(convert.(ComplexF64, Cˢⁱᵈ), fᴷᴼᴺᴮ)
            effective_Lindblad_ops = [DenseOperator(basis, j) for j in effective_Lindblad]

            tout, ρ_t_kossak = timeevolution.master(convert.(Float64, tᵗˢᵗ), ρₒ, DenseOperator(basis, Hˢⁱᵈ), effective_Lindblad_ops)
            ρˢⁱᵈ = [ρₜ.data for ρₜ in ρ_t_kossak]

            F = LiPoSID.fidelity_series(basis, ρₛ, ρˢⁱᵈ)

            h5open(tests_dir*tests_data_file_name,"cw") do fid
                γ_group = open_group(fid, γᵢ)
                t_group = open_group(γ_group, string(t_duration))
                init_state_group = create_group(t_group, state)
                init_state_group["Fidelity"] = convert.(Float64, F)
                init_state_group["tr_dist_grnd"] = LiPoSID.TrDist(ρₛ[1], ρᵍ₀)
                init_state_group["time"] = tᵗˢᵗ
            end

            FminState = minimum(F)
            FmedianState = mean(F)
            FmeanState = mean(F)

            push!(FminStates, FminState)
            push!(FmedianStates, FmedianState)
            push!(FmeanStates, FmeanState)
        end

        F_mean_value = mean(FmeanStates)
        F_median_value = median(FmedianStates)
        F_min_value = minimum(FminStates)

        push!(FminGammas, F_min_value)
        push!(FmedianGammas, F_median_value)
        push!(FmeanGammas, F_mean_value)

        println("Median fidelity for γ = "*γᵢ*" and time duration "*string(t_duration)*": ", F_median_value)

    end
end
    
    
println(tests_data_file_name)
# Out:
#  MULTI DURATION SYSTEM IDENTIFICATION w CONSTRAINED TSSOS and KOSSAKOWSKI Frobenius objective QO simulation
# γ =  0.079477
# Processing time duration: 6.291128250940523
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 8.91799595343345e-7
# Global optimality certified with relative optimality gap 0.000051%!
# Global optimality certified with relative optimality gap 0.000026%!
# minimum(abs.(coefficients(polyGEXY))) = 0.0001876985072750547
# maximum(abs.(coefficients(polyGEXY))) = 226.05632125567843
#  status:GLOBAL runtime :0.965712088
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.079477 and time duration 6.291128250940523: 0.9946717251735337
# Processing time duration: 12.582256501881046
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 8.034223341437921e-7
# Global optimality certified with relative optimality gap 0.000043%!
# Global optimality certified with relative optimality gap 0.000015%!
# minimum(abs.(coefficients(polyGEXY))) = 0.0004546620740722158
# maximum(abs.(coefficients(polyGEXY))) = 365.88037819973215
#  status:GLOBAL runtime :1.675842911
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.079477 and time duration 12.582256501881046: 0.9951694633793824
# Processing time duration: 18.87338475282157
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 5.587156451180547e-7
# Global optimality certified with relative optimality gap 0.000019%!
# Global optimality certified with relative optimality gap 0.000013%!
# minimum(abs.(coefficients(polyGEXY))) = 0.00015463825700230683
# maximum(abs.(coefficients(polyGEXY))) = 450.42156952171655
#  status:GLOBAL runtime :2.418892061
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.079477 and time duration 18.87338475282157: 0.9956392428652283
# γ =  0.25133
# Processing time duration: 1.9894163052560379
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.049228305234873e-6
# Global optimality certified with relative optimality gap 0.000018%!
# Global optimality certified with relative optimality gap 0.000346%!
# minimum(abs.(coefficients(polyGEXY))) = 9.307487558676234e-5
# maximum(abs.(coefficients(polyGEXY))) = 25.15925299229987
#  status:GLOBAL runtime :0.793052199
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 1.9894163052560379: 0.9844518822700776
# Processing time duration: 3.9788326105120757
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.132269735995422e-6
# Global optimality certified with relative optimality gap 0.000039%!
# Global optimality certified with relative optimality gap 0.000400%!
# minimum(abs.(coefficients(polyGEXY))) = 2.5605098767843808e-5
# maximum(abs.(coefficients(polyGEXY))) = 41.03190823996914
#  status:GLOBAL runtime :1.512997514
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 3.9788326105120757: 0.9870228945483884
# Processing time duration: 5.968248915768114
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 3.929221623285021e-6
# Global optimality certified with relative optimality gap 0.000024%!
# Global optimality certified with relative optimality gap 0.000501%!
# minimum(abs.(coefficients(polyGEXY))) = 1.7081512751724605e-5
# maximum(abs.(coefficients(polyGEXY))) = 50.69000952743874
#  status:GLOBAL runtime :2.241378906
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 5.968248915768114: 0.9892231919969208
# Processing time duration: 7.957665221024151
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 3.7960970836269645e-6
# Global optimality certified with relative optimality gap 0.000013%!
# Global optimality certified with relative optimality gap 0.000594%!
# minimum(abs.(coefficients(polyGEXY))) = 8.728685890656297e-5
# maximum(abs.(coefficients(polyGEXY))) = 56.526826742044186
#  status:GLOBAL runtime :3.052106383
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 7.957665221024151: 0.9909667721996721
# Processing time duration: 9.94708152628019
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 3.9209258134415815e-6
# Global optimality certified with relative optimality gap 0.000026%!
# Global optimality certified with relative optimality gap 0.000654%!
# minimum(abs.(coefficients(polyGEXY))) = 9.737164102448438e-5
# maximum(abs.(coefficients(polyGEXY))) = 60.07853609095635
#  status:GLOBAL runtime :3.693662371
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 9.94708152628019: 0.9923231666187606
# Processing time duration: 11.936497831536228
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.068036947119423e-6
# Global optimality certified with relative optimality gap 0.000042%!
# Global optimality certified with relative optimality gap 0.000703%!
# minimum(abs.(coefficients(polyGEXY))) = 0.0001107960659780914
# maximum(abs.(coefficients(polyGEXY))) = 62.22507217452367
#  status:GLOBAL runtime :4.484180437
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 11.936497831536228: 0.9933682745075468
# Processing time duration: 13.925914136792265
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.092072969917798e-6
# Global optimality certified with relative optimality gap 0.000044%!
# Global optimality certified with relative optimality gap 0.000755%!
# minimum(abs.(coefficients(polyGEXY))) = 5.516058303967753e-5
# maximum(abs.(coefficients(polyGEXY))) = 63.52787985867283
#  status:GLOBAL runtime :5.235597491
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 13.925914136792265: 0.9941836535112125
# Processing time duration: 15.915330442048303
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 3.7564202516445963e-6
# Global optimality certified with relative optimality gap 0.000012%!
# Global optimality certified with relative optimality gap 0.000836%!
# minimum(abs.(coefficients(polyGEXY))) = 3.0707036128928926e-5
# maximum(abs.(coefficients(polyGEXY))) = 64.32066206452723
#  status:GLOBAL runtime :5.943822276
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 15.915330442048303: 0.9948307617093902
# Processing time duration: 17.90474674730434
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 3.919384210104294e-6
# Global optimality certified with relative optimality gap 0.000018%!
# Global optimality certified with relative optimality gap 0.000871%!
# minimum(abs.(coefficients(polyGEXY))) = 9.797100255118675e-7
# maximum(abs.(coefficients(polyGEXY))) = 64.79983187935642
#  status:GLOBAL runtime :6.757528352
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 17.90474674730434: 0.9953471010196554
# Processing time duration: 19.89416305256038
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.257071724328273e-6
# Global optimality certified with relative optimality gap 0.000039%!
# Global optimality certified with relative optimality gap 0.000885%!
# minimum(abs.(coefficients(polyGEXY))) = 6.726301311068103e-6
# maximum(abs.(coefficients(polyGEXY))) = 65.09143489697067
#  status:GLOBAL runtime :7.580885667
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 19.89416305256038: 0.9957735295137115
# Processing time duration: 21.883579357816416
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.288545510171641e-6
# Global optimality certified with relative optimality gap 0.000025%!
# Global optimality certified with relative optimality gap 0.000932%!
# minimum(abs.(coefficients(polyGEXY))) = 1.7572436353238245e-5
# maximum(abs.(coefficients(polyGEXY))) = 65.2676633220263
#  status:GLOBAL runtime :8.204281105
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.25133 and time duration 21.883579357816416: 0.9961249037524585
# γ =  0.79477
# Processing time duration: 0.6291128250940524
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.727725518494007e-5
# Global optimality certified with relative optimality gap 0.003605%!
# Global optimality certified with relative optimality gap 0.003605%!
# minimum(abs.(coefficients(polyGEXY))) = 1.115589717234634e-5
# maximum(abs.(coefficients(polyGEXY))) = 2.796040322263776
#  status:GLOBAL runtime :0.643802653
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 0.6291128250940524: 0.9858442878857169
# Processing time duration: 1.2582256501881048
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.261826757825164e-5
# Global optimality certified with relative optimality gap 0.004325%!
# Global optimality certified with relative optimality gap 0.004325%!
# minimum(abs.(coefficients(polyGEXY))) = 5.930188302861535e-5
# maximum(abs.(coefficients(polyGEXY))) = 4.704684769994358
#  status:GLOBAL runtime :1.245855226
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 1.2582256501881048: 0.9882421525796632
# Processing time duration: 1.8873384752821571
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.1112626104683895e-5
# Global optimality certified with relative optimality gap 0.005135%!
# Global optimality certified with relative optimality gap 0.005135%!
# minimum(abs.(coefficients(polyGEXY))) = 4.00165311649297e-5
# maximum(abs.(coefficients(polyGEXY))) = 5.857047392056168
#  status:GLOBAL runtime :1.908191064
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 1.8873384752821571: 0.9903757474840853
# Processing time duration: 2.5164513003762097
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.0536268584410876e-5
# Global optimality certified with relative optimality gap 0.005936%!
# Global optimality certified with relative optimality gap 0.005936%!
# minimum(abs.(coefficients(polyGEXY))) = 4.425311840054478e-5
# maximum(abs.(coefficients(polyGEXY))) = 6.558699347091039
#  status:GLOBAL runtime :2.478996521
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 2.5164513003762097: 0.9920718148470891
# Processing time duration: 3.145564125470262
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.0137818032259266e-5
# Global optimality certified with relative optimality gap 0.006668%!
# Global optimality certified with relative optimality gap 0.006668%!
# minimum(abs.(coefficients(polyGEXY))) = 8.052545782109763e-6
# maximum(abs.(coefficients(polyGEXY))) = 6.983842700409994
#  status:GLOBAL runtime :3.118619672
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 3.145564125470262: 0.9933888202229337
# Processing time duration: 3.7746769505643143
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.033581046502434e-5
# Global optimality certified with relative optimality gap 0.007264%!
# Global optimality certified with relative optimality gap 0.007263%!
# minimum(abs.(coefficients(polyGEXY))) = 1.901113018293933e-5
# maximum(abs.(coefficients(polyGEXY))) = 7.24067929044456
#  status:GLOBAL runtime :3.661970412
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 3.7746769505643143: 0.9943922301743042
# Processing time duration: 4.403789775658367
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.020984976533907e-5
# Global optimality certified with relative optimality gap 0.007813%!
# Global optimality certified with relative optimality gap 0.007813%!
# minimum(abs.(coefficients(polyGEXY))) = 7.4036513040713374e-6
# maximum(abs.(coefficients(polyGEXY))) = 7.397109505103083
#  status:GLOBAL runtime :4.210473966
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 4.403789775658367: 0.9951742158680752
# Processing time duration: 5.032902600752419
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 3.9821072273941054e-5
# Global optimality certified with relative optimality gap 0.008316%!
# Global optimality certified with relative optimality gap 0.008316%!
# minimum(abs.(coefficients(polyGEXY))) = 3.472734755146045e-6
# maximum(abs.(coefficients(polyGEXY))) = 7.49191168585044
#  status:GLOBAL runtime :4.896792557
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 5.032902600752419: 0.9957863399422033
# Processing time duration: 5.662015425846471
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.003282725181243e-5
# Global optimality certified with relative optimality gap 0.008696%!
# Global optimality certified with relative optimality gap 0.008696%!
# minimum(abs.(coefficients(polyGEXY))) = 1.3204307524453921e-5
# maximum(abs.(coefficients(polyGEXY))) = 7.549189464876312
#  status:GLOBAL runtime :5.702559393
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 5.662015425846471: 0.9962718272415394
# Processing time duration: 6.291128250940524
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 4.00900690850567e-5
# Global optimality certified with relative optimality gap 0.009040%!
# Global optimality certified with relative optimality gap 0.009040%!
# minimum(abs.(coefficients(polyGEXY))) = 8.024915712029207e-7
# maximum(abs.(coefficients(polyGEXY))) = 7.584077202058657
#  status:GLOBAL runtime :6.11265352
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 6.291128250940524: 0.9966664836679278
# Processing time duration: 6.920241076034576
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 3.9814748830737356e-5
# Global optimality certified with relative optimality gap 0.009374%!
# Global optimality certified with relative optimality gap 0.009374%!
# minimum(abs.(coefficients(polyGEXY))) = 1.0631332667998736e-5
# maximum(abs.(coefficients(polyGEXY))) = 7.605219721464558
#  status:GLOBAL runtime :6.724159361
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 6.920241076034576: 0.996991080152218
# Processing time duration: 7.549353901128629
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 3.980101149087331e-5
# Global optimality certified with relative optimality gap 0.009644%!
# Global optimality certified with relative optimality gap 0.009643%!
# minimum(abs.(coefficients(polyGEXY))) = 1.4458923114467444e-6
# maximum(abs.(coefficients(polyGEXY))) = 7.617994512959309
#  status:GLOBAL runtime :7.487478205
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 7.549353901128629: 0.9972604135389209
# Processing time duration: 8.17846672622268
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 3.977228998802886e-5
# Global optimality certified with relative optimality gap 0.009887%!
# Global optimality certified with relative optimality gap 0.009887%!
# minimum(abs.(coefficients(polyGEXY))) = 3.099880359233301e-6
# maximum(abs.(coefficients(polyGEXY))) = 7.625776569624139
#  status:GLOBAL runtime :8.076292585
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 0.79477 and time duration 8.17846672622268: 0.9974893096637167
# γ =  2.5133
# Processing time duration: 0.1989416305256038
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.000625470365227833
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00115097.
# The relative optimality gap is: 0.052550%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00115097.
# The relative optimality gap is: 0.052550%.
# optimum = 0.0006261332099463723
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00115097.
# The relative optimality gap is: 0.052483%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00115097.
# The relative optimality gap is: 0.052483%.
# minimum(abs.(coefficients(polyGEXY))) = 1.3200512591324725e-5
# maximum(abs.(coefficients(polyGEXY))) = 0.3509475114740451
#  status:LOCAL/FAIL runtime :1.748703887
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 0.1989416305256038: 0.9919251840446794
# Processing time duration: 0.3978832610512076
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.0005495064202519435
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00097135.
# The relative optimality gap is: 0.042185%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00097135.
# The relative optimality gap is: 0.042185%.
# optimum = 0.0005501125089158102
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00097135.
# The relative optimality gap is: 0.042124%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00097135.
# The relative optimality gap is: 0.042124%.
# minimum(abs.(coefficients(polyGEXY))) = 4.4717735624281655e-6
# maximum(abs.(coefficients(polyGEXY))) = 0.656978198277146
#  status:LOCAL/FAIL runtime :1.148999902
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 0.3978832610512076: 0.9926966222765014
# Processing time duration: 0.5968248915768113
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.0005174806899917552
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00097743.
# The relative optimality gap is: 0.045995%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00097743.
# The relative optimality gap is: 0.045995%.
# optimum = 0.0005155170632335958
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00097743.
# The relative optimality gap is: 0.046192%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00097743.
# The relative optimality gap is: 0.046191%.
# minimum(abs.(coefficients(polyGEXY))) = 3.551486298501832e-6
# maximum(abs.(coefficients(polyGEXY))) = 0.841128320913711
#  status:LOCAL/FAIL runtime :1.531529073
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 0.5968248915768113: 0.994175906538544
# Processing time duration: 0.7957665221024152
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.0005037942611708881
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00103299.
# The relative optimality gap is: 0.052919%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00103299.
# The relative optimality gap is: 0.052919%.
# optimum = 0.0005044751746180247
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00103299.
# The relative optimality gap is: 0.052851%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00103299.
# The relative optimality gap is: 0.052851%.
# minimum(abs.(coefficients(polyGEXY))) = 2.9577725174632466e-6
# maximum(abs.(coefficients(polyGEXY))) = 0.9524497403188064
#  status:LOCAL/FAIL runtime :1.723519226
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 0.7957665221024152: 0.9954079501507979
# Processing time duration: 0.9947081526280189
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.0004990687455404157
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00109034.
# The relative optimality gap is: 0.059127%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00109034.
# The relative optimality gap is: 0.059127%.
# optimum = 0.0004990634363652367
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00109034.
# The relative optimality gap is: 0.059127%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00109034.
# The relative optimality gap is: 0.059128%.
# minimum(abs.(coefficients(polyGEXY))) = 2.58731475509147e-5
# maximum(abs.(coefficients(polyGEXY))) = 1.0197297465990292
#  status:LOCAL/FAIL runtime :2.179170438
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 0.9947081526280189: 0.9963453122025145
# Processing time duration: 1.1936497831536226
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.0004931566494110059
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00113757.
# The relative optimality gap is: 0.064441%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00113757.
# The relative optimality gap is: 0.064441%.
# optimum = 0.0004943297206288923
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00113757.
# The relative optimality gap is: 0.064324%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00113757.
# The relative optimality gap is: 0.064324%.
# minimum(abs.(coefficients(polyGEXY))) = 1.3360364516800222e-5
# maximum(abs.(coefficients(polyGEXY))) = 1.0604640426183485
#  status:LOCAL/FAIL runtime :2.478221653
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 1.1936497831536226: 0.9970335840958735
# Processing time duration: 1.3925914136792266
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.000494037817159767
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00117727.
# The relative optimality gap is: 0.068324%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00117727.
# The relative optimality gap is: 0.068324%.
# optimum = 0.0004933963781132204
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00117727.
# The relative optimality gap is: 0.068388%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00117727.
# The relative optimality gap is: 0.068388%.
# minimum(abs.(coefficients(polyGEXY))) = 1.605041043286485e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.0852662802017379
#  status:LOCAL/FAIL runtime :2.885483728
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 1.3925914136792266: 0.9975470469966745
# Processing time duration: 1.5915330442048303
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.000491286587269282
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00121309.
# The relative optimality gap is: 0.072181%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00121309.
# The relative optimality gap is: 0.072181%.
# optimum = 0.0004912665667339426
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00121309.
# The relative optimality gap is: 0.072183%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00121309.
# The relative optimality gap is: 0.072183%.
# minimum(abs.(coefficients(polyGEXY))) = 1.0177237303530945e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.100165705972977
#  status:LOCAL/FAIL runtime :3.591634659
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 1.5915330442048303: 0.9979350650075236
# Processing time duration: 1.790474674730434
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.0004948315908260509
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00124558.
# The relative optimality gap is: 0.075075%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00124558.
# The relative optimality gap is: 0.075075%.
# optimum = 0.0004954562515325993
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00124558.
# The relative optimality gap is: 0.075012%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00124558.
# The relative optimality gap is: 0.075012%.
# minimum(abs.(coefficients(polyGEXY))) = 1.1611487883876782e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.1092089169645876
#  status:LOCAL/FAIL runtime :3.724378534
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 1.790474674730434: 0.9982362473115084
# Processing time duration: 1.9894163052560379
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.0004924021156755062
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00127364.
# The relative optimality gap is: 0.078124%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00127364.
# The relative optimality gap is: 0.078124%.
# optimum = 0.0004960180724100487
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00127364.
# The relative optimality gap is: 0.077763%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00127364.
# The relative optimality gap is: 0.077763%.
# minimum(abs.(coefficients(polyGEXY))) = 9.41101269364003e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.1146887214644505
#  status:LOCAL/FAIL runtime :4.129985511
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 1.9894163052560379: 0.9984736887826476
# Processing time duration: 2.1883579357816414
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.0004963272883632094
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00129725.
# The relative optimality gap is: 0.080092%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00129725.
# The relative optimality gap is: 0.080092%.
# optimum = 0.0004966338862268782
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00129725.
# The relative optimality gap is: 0.080061%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00129725.
# The relative optimality gap is: 0.080061%.
# minimum(abs.(coefficients(polyGEXY))) = 2.571377383719953e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.1180122007347335
#  status:LOCAL/FAIL runtime :4.434744872
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 2.1883579357816414: 0.9986631463891875
# Processing time duration: 2.387299566307245
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.0004938152568127981
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00131752.
# The relative optimality gap is: 0.082371%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00131752.
# The relative optimality gap is: 0.082371%.
# optimum = 0.0004972321269643663
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00131752.
# The relative optimality gap is: 0.082029%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00131752.
# The relative optimality gap is: 0.082029%.
# minimum(abs.(coefficients(polyGEXY))) = 7.242200068176601e-7
# maximum(abs.(coefficients(polyGEXY))) = 1.1200280581439124
#  status:LOCAL/FAIL runtime :4.933861156
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 2.387299566307245: 0.9988166271139751
# Processing time duration: 2.5862411968328494
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.000498092388355188
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00133558.
# The relative optimality gap is: 0.083748%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00133558.
# The relative optimality gap is: 0.083748%.
# optimum = 0.0004973952487195212
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00133558.
# The relative optimality gap is: 0.083818%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00133558.
# The relative optimality gap is: 0.083818%.
# minimum(abs.(coefficients(polyGEXY))) = 2.146499880293093e-6
# maximum(abs.(coefficients(polyGEXY))) = 1.1212499654292567
#  status:LOCAL/FAIL runtime :5.254419141
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 2.5133 and time duration 2.5862411968328494: 0.9989429006563622
# γ =  7.9477
# Processing time duration: 0.06291128250940524
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.0009658668262348116
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00202757.
# The relative optimality gap is: 0.106171%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00202757.
# The relative optimality gap is: 0.106171%.
# optimum = 0.0011346506353064958
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00202757.
# The relative optimality gap is: 0.089292%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00202757.
# The relative optimality gap is: 0.089292%.
# minimum(abs.(coefficients(polyGEXY))) = 1.424748982428285e-6
# maximum(abs.(coefficients(polyGEXY))) = 0.010934293963695418
#  status:LOCAL/FAIL runtime :0.410703096
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 7.9477 and time duration 0.06291128250940524: 0.9869125126432663
# Processing time duration: 0.12582256501881048
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.00623624401272663
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00976263.
# The relative optimality gap is: 0.352639%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00976263.
# The relative optimality gap is: 0.352639%.
# optimum = 0.006625234805952969
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00976263.
# The relative optimality gap is: 0.313739%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00976263.
# The relative optimality gap is: 0.313739%.
# minimum(abs.(coefficients(polyGEXY))) = 2.700706449367321e-6
# maximum(abs.(coefficients(polyGEXY))) = 0.05756404778182847
#  status:LOCAL/FAIL runtime :0.646102972
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 7.9477 and time duration 0.12582256501881048: 0.9968032853080333
# Processing time duration: 0.1887338475282157
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# optimum = 0.007284704696888123
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01254593.
# The relative optimality gap is: 0.526123%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01254593.
# The relative optimality gap is: 0.526123%.
# optimum = 0.008537644524294525
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01254593.
# The relative optimality gap is: 0.400829%.
# ...
# minimum(abs.(coefficients(polyGEXY))) = 1.3786832889951853e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726746818767818
#  status:LOCAL/FAIL runtime :2.545111045
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.04376715871563283: 0.9995638991987996
# Processing time duration: 0.04575657502088887
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6300280044784102
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12745368.
# The relative optimality gap is: 50.257432%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12745368.
# The relative optimality gap is: 50.257432%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.7089403852755306
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12745368.
# The relative optimality gap is: 58.148671%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12745368.
# The relative optimality gap is: 58.148671%.
# minimum(abs.(coefficients(polyGEXY))) = 1.4041459032883472e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726788419331954
#  status:LOCAL/FAIL runtime :2.56021488
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.04575657502088887: 0.9995517541084838
# Processing time duration: 0.047745991326144904
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: FEASIBLE_POINT
# optimum = 0.562683281313605
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12802785.
# The relative optimality gap is: 43.465544%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12802785.
# The relative optimality gap is: 43.465544%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.7103798045584158
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12802785.
# The relative optimality gap is: 58.235196%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12802785.
# The relative optimality gap is: 58.235196%.
# minimum(abs.(coefficients(polyGEXY))) = 1.427762041175327e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.037268206847692546
#  status:LOCAL/FAIL runtime :2.70184444
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.047745991326144904: 0.9995402929444199
# Processing time duration: 0.04973540763140095
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6246707509964387
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12859532.
# The relative optimality gap is: 49.607543%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12859532.
# The relative optimality gap is: 49.607543%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.7378851226647936
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12859532.
# The relative optimality gap is: 60.928980%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12859532.
# The relative optimality gap is: 60.928980%.
# minimum(abs.(coefficients(polyGEXY))) = 1.449806282620674e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726845798582611
#  status:LOCAL/FAIL runtime :2.7012728
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.04973540763140095: 0.9995290096491037
# Processing time duration: 0.051724823936656984
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6912154723676329
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12913793.
# The relative optimality gap is: 56.207754%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12913793.
# The relative optimality gap is: 56.207754%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6195881711687143
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12913793.
# The relative optimality gap is: 49.045024%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12913793.
# The relative optimality gap is: 49.045024%.
# minimum(abs.(coefficients(polyGEXY))) = 1.4699065804086996e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726864827828231
#  status:LOCAL/FAIL runtime :2.902139195
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.051724823936656984: 0.9995182683506485
# Processing time duration: 0.05371424024191302
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6505069413209157
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12966447.
# The relative optimality gap is: 52.084247%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12966447.
# The relative optimality gap is: 52.084247%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6374498032415278
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12966447.
# The relative optimality gap is: 50.778533%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.12966447.
# The relative optimality gap is: 50.778533%.
# minimum(abs.(coefficients(polyGEXY))) = 1.4878882872758733e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726879822798611
#  status:LOCAL/FAIL runtime :2.947614783
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.05371424024191302: 0.999507883972107
# Processing time duration: 0.05570365654716906
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6365967828553752
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13016830.
# The relative optimality gap is: 50.642848%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13016830.
# The relative optimality gap is: 50.642848%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.7230260563141333
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13016830.
# The relative optimality gap is: 59.285776%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13016830.
# The relative optimality gap is: 59.285776%.
# minimum(abs.(coefficients(polyGEXY))) = 1.503627728885545e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726891042801075
#  status:LOCAL/FAIL runtime :3.17191901
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.05570365654716906: 0.9994979389039795
# Processing time duration: 0.057693072852425094
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.8094579223812428
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13063908.
# The relative optimality gap is: 67.881884%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13063908.
# The relative optimality gap is: 67.881884%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.7176799556339778
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13063908.
# The relative optimality gap is: 58.704087%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13063908.
# The relative optimality gap is: 58.704087%.
# minimum(abs.(coefficients(polyGEXY))) = 1.5173222216083247e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.037268995296439754
#  status:LOCAL/FAIL runtime :3.153728404
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.057693072852425094: 0.9994887425984169
# Processing time duration: 0.05968248915768113
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6552849195074361
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13110627.
# The relative optimality gap is: 52.417865%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13110627.
# The relative optimality gap is: 52.417865%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.5518378531317694
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13110627.
# The relative optimality gap is: 42.073158%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13110627.
# The relative optimality gap is: 42.073158%.
# minimum(abs.(coefficients(polyGEXY))) = 1.5295791342445694e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.0372690639516831
#  status:LOCAL/FAIL runtime :3.270548299
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.05968248915768113: 0.9994795462471615
# Processing time duration: 0.061671905462937174
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6959352652786206
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13155239.
# The relative optimality gap is: 56.438288%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13155239.
# The relative optimality gap is: 56.438288%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6358208044544821
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13155239.
# The relative optimality gap is: 50.426842%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13155239.
# The relative optimality gap is: 50.426842%.
# minimum(abs.(coefficients(polyGEXY))) = 1.540177055201738e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.03726911718994345
#  status:LOCAL/FAIL runtime :3.417695824
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.061671905462937174: 0.9994707526394424
# Processing time duration: 0.06366132176819321
# *********************************** TSSOS ***********************************
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [8, 7]
# [1, 1]
# -----------------------------------------------------------------------------
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.7302949270030136
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13198131.
# The relative optimality gap is: 59.831362%.
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13198131.
# The relative optimality gap is: 59.831362%.
# termination status: SLOW_PROGRESS
# solution status: UNKNOWN_RESULT_STATUS
# optimum = 0.6598721642388464
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13198131.
# The relative optimality gap is: 52.789085%.
# No higher TS step of the CS-TSSOS hierarchy!
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.13198131.
# The relative optimality gap is: 52.789085%.
# minimum(abs.(coefficients(polyGEXY))) = 1.5495896322667652e-9
# maximum(abs.(coefficients(polyGEXY))) = 0.037269158894470966
#  status:LOCAL/FAIL runtime :3.490639458
# Processing state: D1
# Processing state: D2
# Processing state: D3
# Processing state: D4
# Processing state: D5
# Processing state: D6
# Processing state: D7
# Processing state: D8
# Processing state: D9
# Processing state: D10
# Median fidelity for γ = 251.33 and time duration 0.06366132176819321: 0.9994622548318306
# MULT_KOSSAK_CONSTR_TSSOS_threshold_1e-15_FROB_QO_2024-Sep-29_at_19-00.h5

# %%
println(tests_data_file_name)
# Out:
# MULT_KOSSAK_CONSTR_TSSOS_threshold_1e-15_FROB_QO_2024-Sep-29_at_19-00.h5
